# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import tensorflow as tf
import os, sys, time
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import utils, optimization, metrics, plot
import pickle

# %% [markdown]
# # Parameters

# %%
spix = 256
path = '../data/size{}_splits1000_n500x3/'.format(spix)
input_pattern = 'Box_70*snapshot_050'
file_ext = '.dat'
k = 10

# %% [markdown]
# # Data handling

# %% [markdown]
# Load the data

# %%
queue = []
for file in os.listdir(path):
    if file.endswith(file_ext) and (np.all([x in file for x in input_pattern.split("*")])):
        queue.append(os.path.join(path, file))
nsamples = len(queue)
print('They are {} "{}" files.'.format(nsamples, file_ext))
# Out:
# They are 15000 ".dat" files.

# %%
# nsamples = 5000
input_img = np.vstack(map(lambda i:np.fromfile(queue[i], dtype=float32), range(nsamples)))
input_img.resize([nsamples,spix,spix])

# %%
input_img = utils.forward_map(input_img,k)

# input_img = np.log(input_img+0.001)

# p = np.random.permutation(nsamples)
# input_img = input_img[p,]

# %% [markdown]
# Let us plot 16 images

# %%
plt.figure(figsize=(15,15))
utils.draw_images(input_img,nx=10,ny=10,px=spix,py=spix)

# %% [markdown]
# Let us make small patches of 64 :-)

# %%
ns = 256
cut = spix//ns
img_small = np.zeros([nsamples*cut*cut, ns, ns])
for i in range(cut):
    for j in range(cut):
        l = j + i*cut 
        img_small[l*nsamples:(l+1)*nsamples,:,:] = input_img[:,i*ns:(i+1)*ns,j*ns:(j+1)*ns]


# # Reduce the size
# ns = 64
# cut = spix//ns
# img_small = input_img[:,:ns,:ns].copy()
# del input_img

# %%
plt.figure(figsize=(15,15))
utils.draw_images(img_small,nx=4,ny=4,px=ns,py=ns)

# %% [markdown]
# # A) The WGAN

# %%
def current_time_str():
    import time, datetime
    d = datetime.datetime.fromtimestamp(time.time())
    return str(d.year)+ '_' + str(d.month)+ '_' + str(d.day)+ '_' + str(d.hour)+ '_' + str(d.minute)

time_str = current_time_str() 
global_path = '../../saved_result/'

# %% [markdown]
# ## Parameters

# %%
bn = False
params_discriminator = dict()
params_discriminator['stride'] = [2, 2, 2, 2, 2, 1]
params_discriminator['nfilter'] = [16, 32, 64, 128, 256, 32]
params_discriminator['shape'] = [[5, 5],[5, 5], [5, 5], [5, 5], [3, 3], [3, 3]]
params_discriminator['batch_norm'] = [bn, bn, bn, bn, bn, bn]
params_discriminator['full'] = [256]
params_discriminator['summary'] = True

params_generator = dict()
params_generator['stride'] = [2, 2, 2, 2, 2, 1]
params_generator['latent_dim'] = 100
params_generator['nfilter'] = [32, 64, 128, 256, 128, 1]
params_generator['shape'] = [[3, 3], [3, 3], [5, 5], [5, 5], [5, 5], [5, 5]]
params_generator['batch_norm'] = [bn, bn, bn, bn, bn]
params_generator['full'] = [8*8*32]
params_generator['summary'] = True
params_generator['non_lin'] = 'tanh'

params_optimization = dict()
params_optimization['gamma_gp'] = 10
params_optimization['batch_size'] = 16
params_optimization['optimizer'] = 'adam' # rmsprop / adam
params_optimization['disc_learning_rate'] = 3e-4
params_optimization['gen_learning_rate'] = 3e-4
params_optimization['beta1'] = 0.0
params_optimization['beta2'] = 0.9
params_optimization['epsilon'] = 1e-8
params_optimization['epoch'] = 50

params = dict()
params['generator'] = params_generator
params['discriminator'] = params_discriminator
params['optimization'] = params_optimization

params['image_size'] = [ns, ns]
params['sum_every'] = 200
params['viz_every'] = 200
params['save_every'] = 2000
params['name'] = 'WGAN{}'.format(ns)
params['summary_dir'] = global_path + params['name'] + '_' + time_str +'summary/'
params['save_dir'] = global_path + params['name'] + '_' + time_str + 'checkpoints/'

params['clip_max_real'] = False
params['log_clip'] = 0.1
params['sigma_smooth'] = 1
params['k'] = k

# %% [markdown]
# ## Build the model

# %%
from model import WGanModel
from gan import GAN

wgan = GAN(params, WGanModel)
# Out:
# Generator
# ------------------------------------------------------------
#      The input is of size (?, 100)
#      0 Full layer with 2048 outputs
#          Size of the variables: (?, 2048)
#      Reshape to (?, 8, 8, 32)
#      1 Deconv layer with 32 channels
#          Batch norm
#          Size of the variables: (?, 16, 16, 32)
#      2 Deconv layer with 64 channels
#          Batch norm
#          Size of the variables: (?, 32, 32, 64)
#      3 Deconv layer with 128 channels
#          Batch norm
#          Size of the variables: (?, 64, 64, 128)
#      4 Deconv layer with 256 channels
#          Batch norm
#          Size of the variables: (?, 128, 128, 256)
#      5 Deconv layer with 128 channels
#          Batch norm
#          Size of the variables: (?, 256, 256, 128)
#      6 Deconv layer with 1 channels
#          Size of the variables: (?, 256, 256, 1)
#     Non lienarity: tanh
#      The output is of size (?, 256, 256, 1)
# ------------------------------------------------------------
#
# Discriminator
# ------------------------------------------------------------
#      The input is of size (?, 256, 256, 1)
#      0 Conv layer with 16 channels
#          Size of the variables: (?, 128, 128, 16)
#      1 Conv layer with 32 channels
#          Size of the variables: (?, 64, 64, 32)
#      2 Conv layer with 64 channels
#          Size of the variables: (?, 32, 32, 64)
#      3 Conv layer with 128 channels
#          Size of the variables: (?, 16, 16, 128)
#      4 Conv layer with 256 channels
#          Size of the variables: (?, 8, 8, 256)
#      5 Conv layer with 32 channels
#          Size of the variables: (?, 8, 8, 32)
#      Reshape to (?, 2048)
#      6 Full layer with 256 outputs
#          Size of the variables: (?, 256)
#      7 Full layer with 1 outputs
#      The output is of size (?, 1)
# ------------------------------------------------------------
#
# ---------
# Variables: name (type shape) [size]
# ---------
# generator/0_full/Matrix:0 (float32_ref 100x2048) [204800, bytes: 819200]
# generator/0_full/bias:0 (float32_ref 2048) [2048, bytes: 8192]
# generator/0_deconv/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/0_deconv/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_deconv/w:0 (float32_ref 3x3x64x32) [18432, bytes: 73728]
# generator/1_deconv/biases:0 (float32_ref 64) [64, bytes: 256]
# generator/2_deconv/w:0 (float32_ref 5x5x128x64) [204800, bytes: 819200]
# generator/2_deconv/biases:0 (float32_ref 128) [128, bytes: 512]
# generator/3_deconv/w:0 (float32_ref 5x5x256x128) [819200, bytes: 3276800]
# generator/3_deconv/biases:0 (float32_ref 256) [256, bytes: 1024]
# generator/4_deconv/w:0 (float32_ref 5x5x128x256) [819200, bytes: 3276800]
# generator/4_deconv/biases:0 (float32_ref 128) [128, bytes: 512]
# generator/5_deconv/w:0 (float32_ref 5x5x1x128) [3200, bytes: 12800]
# generator/5_deconv/biases:0 (float32_ref 1) [1, bytes: 4]
# discriminator/0_conv/w:0 (float32_ref 5x5x1x16) [400, bytes: 1600]
# discriminator/0_conv/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/1_conv/w:0 (float32_ref 5x5x16x32) [12800, bytes: 51200]
# discriminator/1_conv/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/2_conv/w:0 (float32_ref 5x5x32x64) [51200, bytes: 204800]
# discriminator/2_conv/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/3_conv/w:0 (float32_ref 5x5x64x128) [204800, bytes: 819200]
# discriminator/3_conv/biases:0 (float32_ref 128) [128, bytes: 512]
# discriminator/4_conv/w:0 (float32_ref 3x3x128x256) [294912, bytes: 1179648]
# discriminator/4_conv/biases:0 (float32_ref 256) [256, bytes: 1024]
# discriminator/5_conv/w:0 (float32_ref 3x3x256x32) [73728, bytes: 294912]
# discriminator/5_conv/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/6_full/Matrix:0 (float32_ref 2048x256) [524288, bytes: 2097152]
# discriminator/6_full/bias:0 (float32_ref 256) [256, bytes: 1024]
# discriminator/out/Matrix:0 (float32_ref 256x1) [256, bytes: 1024]
# discriminator/out/bias:0 (float32_ref 1) [1, bytes: 4]
# Total size of variables: 3244674
# Total bytes of variables: 12978696

# %% [markdown]
# ## Train the model
# Note that the input is the processed data... Maybe, we should change that

# %%
wgan.train(img_small)
# Out:
# Erease recursively directory: ../../saved_result/WGAN256_2018_1_13_14_25summary/

# %% [markdown]
# ## Use the model
# Generate a few samples...

# %%
import plot
gen_sample, gen_sample_raw = wgan.generate()
plot.plot_images_psd(gen_sample_raw,'' , sigma_smooth = [0,0.5,1])
