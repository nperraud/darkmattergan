# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# import sys
# sys.path.insert(0, '../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"


import numpy as np
import tensorflow as tf

from gantools import data
from gantools import utils
from gantools import plot
from gantools.model import CosmoWGAN, WGAN, LapWGAN, UpscalePatchWGAN
from gantools.gansystem import GANsystem, UpscaleGANsystem
from gantools.data import fmap
from gantools import evaluation
import functools
import matplotlib.pyplot as plt
from copy import deepcopy

# %% [markdown]
# # Parameters

# %%
ns = 32 # Resolution of the image
try_resume = True # Try to resume previous simulation
Mpch = 350 # Type of dataset (select 70 or 350)

# Do not change these for now
# shift = 3
# c = 40000
# forward = functools.partial(fmap.stat_forward, shift=shift, c=c)
# backward = functools.partial(fmap.stat_backward, shift=shift, c=c)

forward = fmap.stat_forward
backward = fmap.stat_backward

# %% [markdown]
# # Data handling

# %% [markdown]
# Load the data

# %%
dataset = data.load.load_nbody_dataset(nsamples=10, spix=ns, Mpch=Mpch, forward_map=forward, patch=True, is_3d=False)
# Out:
# Select 10 samples out of 30.
# images shape =  (10, 256, 256, 256)

# %%
# The dataset can return an iterator.
it = dataset.iter(10)
print(next(it).shape)
del it
# Out:
# (10, 32, 32, 4)

# %%
# Get all the data
X = dataset.get_all_data()[:,:,:,0].flatten()

# %%
# Check that the backward maps invert the forward map.
# assert(np.sum(np.abs(forward(backward(X))-X))< 5)
# # For debugging
# np.sum(np.abs(forward(backward(X))-X))
# forward(backward(X))-X
# x = np.arange(1e4)
# plt.plot(x, backward(forward(x))-x)

# %%
np.sum(np.abs(forward(backward(X))-X))
# Out:
# 2.0770624

# %% [markdown]
# Display the histogram of the pixel densities after the forward map

# %%
plt.hist(X, 100)
print('min: {}'.format(np.min(X)))
print('max: {}'.format(np.max(X)))
plt.yscale('log')
# Out:
# min: 0.0
# max: 6.077099323272705

# %%
# to free some memory
del X

# %% [markdown]
# Let us plot 16 images

# %%
plt.figure(figsize=(15,15))
plot.draw_images(dataset.get_samples(N=16)[:,:,:,0],nx=4,ny=4);
plt.title("Real samples")
# Out:
# Text(0.5,1,'Real samples')

# %% [markdown]
# # Define parameters for the WGAN

# %%
time_str = '2D_patchgan_psd_features'
global_path = 'saved_results'

name = 'WGAN{}'.format(ns) + '_' + time_str

# %% [markdown]
# ## Parameters

# %%
bn = False

md=32

params_discriminator = dict()

params_discriminator['stride'] = [2, 2, 2, 1, 1, 1]
params_discriminator['nfilter'] = [2*md, 2*md, md, md//2, md//4,2]
params_discriminator['shape'] = [[4, 4],[4, 4], [4, 4],[4, 4], [4, 4], [4, 4]]
params_discriminator['batch_norm'] = [bn, bn, bn, bn, bn, bn]
params_discriminator['full'] = [64, 16]
params_discriminator['minibatch_reg'] = False
params_discriminator['summary'] = True
params_discriminator['data_size'] = 2
params_discriminator['inception'] = True
params_discriminator['spectral_norm'] = False
params_discriminator['fft_features'] = False
params_discriminator['psd_features'] = True

params_generator = dict()
params_generator['stride'] = [1, 1, 1, 1, 1, 1, 1, 1]
params_generator['latent_dim'] = 32*32
params_generator['latent_dim_split'] = None
params_generator['in_conv_shape'] =[32, 32]
params_generator['nfilter'] = [md, md, md, md, md, md, md, 1]
params_generator['shape'] = [[4, 4],[4, 4], [4, 4],[4, 4], [4, 4], [4, 4]]
params_generator['batch_norm'] = [bn, bn, bn, bn,bn, bn, bn]
params_generator['full'] = []
params_generator['summary'] = True
params_generator['non_lin'] = tf.nn.relu
params_generator['data_size'] = 2
params_generator['inception'] = True
params_generator['spectral_norm'] = False
params_generator['use_Xdown'] = False
params_generator['weights_border'] = True


# Optimization parameters inspired from 'Self-Attention Generative Adversarial Networks'
# - Spectral normalization GEN DISC
# - Batch norm GEN
# - TTUR ('GANs Trained by a Two Time-Scale Update Rule Converge to a Local Nash Equilibrium')
# - ADAM  beta1=0 beta2=0.9, disc lr 0.0004, gen lr 0.0001
# - Hinge loss
# Parameters are similar to the ones in those papers...
# - 'PROGRESSIVE GROWING OF GANS FOR IMPROVED QUALITY, STABILITY, AND VARIATION'
# - 'LARGE SCALE GAN TRAINING FOR HIGH FIDELITY NATURAL IMAGE SYNTHESIS'
# - 'CGANS WITH PROJECTION DISCRIMINATOR'

params_optimization = dict()
params_optimization['batch_size'] = 8
params_optimization['epoch'] = 100
params_optimization['n_critic'] = 5
# params_optimization['generator'] = dict()
# params_optimization['generator']['optimizer'] = 'adam'
# params_optimization['generator']['kwargs'] = {'beta1':0, 'beta2':0.9}
# params_optimization['generator']['learning_rate'] = 0.0004
# params_optimization['discriminator'] = dict()
# params_optimization['discriminator']['optimizer'] = 'adam'
# params_optimization['discriminator']['kwargs'] = {'beta1':0, 'beta2':0.9}
# params_optimization['discriminator']['learning_rate'] = 0.0001

# Cosmology parameters
params_cosmology = dict()
params_cosmology['forward_map'] = forward
params_cosmology['backward_map'] = backward


# all parameters
params = dict()
params['net'] = dict() # All the parameters for the model
params['net']['generator'] = params_generator
params['net']['discriminator'] = params_discriminator
params['net']['cosmology'] = params_cosmology # Parameters for the cosmological summaries
params['net']['prior_distribution'] = 'gaussian'
params['net']['shape'] = [ns, ns, 4] # Shape of the image
params['net']['loss_type'] = 'normalized_wasserstein' # loss ('hinge' or 'wasserstein')
params['net']['gamma_gp'] = 10 # Gradient penalty
params['net']['upscaling'] = 4 

params['optimization'] = params_optimization
params['summary_every'] = 200 # Tensorboard summaries every ** iterations
params['print_every'] = 50 # Console summaries every ** iterations
params['save_every'] = 1000 # Save the model every ** iterations
params['summary_dir'] = os.path.join(global_path, name +'_summary/')
params['save_dir'] = os.path.join(global_path, name + '_checkpoints/')
params['Nstats'] = 1000
params['Nstats_cubes'] = 256

# %%
resume, params = utils.test_resume(try_resume, params)
# If a model is reloaded and some parameters have to be changed, then it should be done here.
# For example, setting the number of epoch to 5 would be:
params['optimization']['epoch'] = 5
params['Nstats_cubes'] = 256
# Out:
# Resume, the training will start from the last iteration!

# %% [markdown]
# # Build the model

# %%
class CosmoUpscalePatchWGAN(UpscalePatchWGAN, CosmoWGAN):
    pass
wgan = UpscaleGANsystem(CosmoUpscalePatchWGAN, params)
# Out:
# Apply attenuation to borders
# Generator
# --------------------------------------------------
#      The input is of size (?, 1024)
#      Reshape to (?, 32, 32, 1)
#      Contenate with latent variables to (?, 32, 32, 5)
#      0 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      1 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      2 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      3 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      4 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      5 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      6 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      7 Inception conv(1x1,3x3,5x5) layer with 1 channels
#          Size of the variables: (?, 32, 32, 1)
#     Costum non linearity: <function relu at 0x7fa921178510>
#      The output is of size (?, 32, 32, 1)
# --------------------------------------------------
#
# Use PSD features
# Discriminator
# --------------------------------------------------
#      The input is of size (?, 64, 64, 3)
#      0 Inception(1x1,3x3,5x5) layer with 64 channels
#          Size of the variables: (?, 32, 32, 64)
#      1 Inception(1x1,3x3,5x5) layer with 64 channels
#          Size of the variables: (?, 16, 16, 64)
#      2 Inception(1x1,3x3,5x5) layer with 32 channels
#          Size of the variables: (?, 8, 8, 32)
#      3 Inception(1x1,3x3,5x5) layer with 16 channels
#          Size of the variables: (?, 8, 8, 16)
#      4 Inception(1x1,3x3,5x5) layer with 8 channels
#          Size of the variables: (?, 8, 8, 8)
#      5 Inception(1x1,3x3,5x5) layer with 2 channels
#          Size of the variables: (?, 8, 8, 2)
#      Reshape to (?, 128)
#      Contenate with psd_features to (?, 585)
#      6 Full layer with 64 outputs
#          Size of the variables: (?, 64)
#      7 Full layer with 16 outputs
#          Size of the variables: (?, 16)
#      8 Full layer with 1 outputs
#      The output is of size (?, 1)
# --------------------------------------------------
#
#  Wasserstein loss with gamma_gp=10
#  Using gradients penalty
# Add summary for descriptives/mean_real
# Add summary for descriptives/var_real
# Add summary for descriptives/min_real
# Add summary for descriptives/max_real
# Add summary for descriptives/kurtosis_real
# Add summary for descriptives/skewness_real
# Add summary for descriptives/median_real
# Add summary for descriptives/mean_fake
# Add summary for descriptives/var_fake
# Add summary for descriptives/min_fake
# Add summary for descriptives/max_fake
# Add summary for descriptives/kurtosis_fake
# Add summary for descriptives/skewness_fake
# Add summary for descriptives/median_fake
# Add summary for descriptives/mean_l2
# Add summary for descriptives/var_l2
# Add summary for descriptives/min_l2
# Add summary for descriptives/max_l2
# Add summary for descriptives/kurtosis_l2
# Add summary for descriptives/skewness_l2
# Add summary for descriptives/median_l2
# Add summary for cosmology/mass_histogram_l2log
# Add summary for cosmology/peak_histogram_l2log
# Add summary for cosmology/psd_l2log
# Add summary for cosmology/global_score
#
# Build the optimizers:
#  * discriminator
# kwargs: {}
# learning_rate: 3.0e-05
# optimizer: rmsprop
#
#  * generator
# kwargs: {}
# learning_rate: 3.0e-05
# optimizer: rmsprop
#
# ---------
# Variables: name (type shape) [size]
# ---------
# generator/0_conv_1_by_1/w:0 (float32_ref 1x1x5x32) [160, bytes: 640]
# generator/0_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/0_conv_3_by_3/w:0 (float32_ref 3x3x5x32) [1440, bytes: 5760]
# generator/0_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/0_conv_5_by_5/w:0 (float32_ref 5x5x5x32) [4000, bytes: 16000]
# generator/0_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/0_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/0_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/1_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/1_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/1_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/1_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/2_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/2_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/2_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/2_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/3_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/3_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/3_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/3_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/4_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/4_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/4_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/4_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/5_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/5_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/5_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/5_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/6_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/6_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/6_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/6_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/7_conv_1_by_1/w:0 (float32_ref 1x1x32x1) [32, bytes: 128]
# generator/7_conv_1_by_1/biases:0 (float32_ref 1) [1, bytes: 4]
# generator/7_conv_3_by_3/w:0 (float32_ref 3x3x32x1) [288, bytes: 1152]
# generator/7_conv_3_by_3/biases:0 (float32_ref 1) [1, bytes: 4]
# generator/7_conv_5_by_5/w:0 (float32_ref 5x5x32x1) [800, bytes: 3200]
# generator/7_conv_5_by_5/biases:0 (float32_ref 1) [1, bytes: 4]
# generator/7_conv_1_by_1_merge/w:0 (float32_ref 1x1x3x1) [3, bytes: 12]
# generator/7_conv_1_by_1_merge/biases:0 (float32_ref 1) [1, bytes: 4]
# discriminator/0_conv_1_by_1/w:0 (float32_ref 1x1x3x64) [192, bytes: 768]
# discriminator/0_conv_1_by_1/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/0_conv_3_by_3/w:0 (float32_ref 3x3x3x64) [1728, bytes: 6912]
# discriminator/0_conv_3_by_3/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/0_conv_5_by_5/w:0 (float32_ref 5x5x3x64) [4800, bytes: 19200]
# discriminator/0_conv_5_by_5/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/0_conv_1_by_1_merge/w:0 (float32_ref 1x1x192x64) [12288, bytes: 49152]
# discriminator/0_conv_1_by_1_merge/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_1_by_1/w:0 (float32_ref 1x1x64x64) [4096, bytes: 16384]
# discriminator/1_conv_1_by_1/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_3_by_3/w:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# discriminator/1_conv_3_by_3/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_5_by_5/w:0 (float32_ref 5x5x64x64) [102400, bytes: 409600]
# discriminator/1_conv_5_by_5/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_1_by_1_merge/w:0 (float32_ref 1x1x192x64) [12288, bytes: 49152]
# discriminator/1_conv_1_by_1_merge/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/2_conv_1_by_1/w:0 (float32_ref 1x1x64x32) [2048, bytes: 8192]
# discriminator/2_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/2_conv_3_by_3/w:0 (float32_ref 3x3x64x32) [18432, bytes: 73728]
# discriminator/2_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/2_conv_5_by_5/w:0 (float32_ref 5x5x64x32) [51200, bytes: 204800]
# discriminator/2_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/2_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# discriminator/2_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/3_conv_1_by_1/w:0 (float32_ref 1x1x32x16) [512, bytes: 2048]
# discriminator/3_conv_1_by_1/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/3_conv_3_by_3/w:0 (float32_ref 3x3x32x16) [4608, bytes: 18432]
# discriminator/3_conv_3_by_3/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/3_conv_5_by_5/w:0 (float32_ref 5x5x32x16) [12800, bytes: 51200]
# discriminator/3_conv_5_by_5/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/3_conv_1_by_1_merge/w:0 (float32_ref 1x1x48x16) [768, bytes: 3072]
# discriminator/3_conv_1_by_1_merge/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/4_conv_1_by_1/w:0 (float32_ref 1x1x16x8) [128, bytes: 512]
# discriminator/4_conv_1_by_1/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/4_conv_3_by_3/w:0 (float32_ref 3x3x16x8) [1152, bytes: 4608]
# discriminator/4_conv_3_by_3/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/4_conv_5_by_5/w:0 (float32_ref 5x5x16x8) [3200, bytes: 12800]
# discriminator/4_conv_5_by_5/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/4_conv_1_by_1_merge/w:0 (float32_ref 1x1x24x8) [192, bytes: 768]
# discriminator/4_conv_1_by_1_merge/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/5_conv_1_by_1/w:0 (float32_ref 1x1x8x2) [16, bytes: 64]
# discriminator/5_conv_1_by_1/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/5_conv_3_by_3/w:0 (float32_ref 3x3x8x2) [144, bytes: 576]
# discriminator/5_conv_3_by_3/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/5_conv_5_by_5/w:0 (float32_ref 5x5x8x2) [400, bytes: 1600]
# discriminator/5_conv_5_by_5/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/5_conv_1_by_1_merge/w:0 (float32_ref 1x1x6x2) [12, bytes: 48]
# discriminator/5_conv_1_by_1_merge/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/6_full/Matrix:0 (float32_ref 585x64) [37440, bytes: 149760]
# discriminator/6_full/bias:0 (float32_ref 64) [64, bytes: 256]
# discriminator/7_full/Matrix:0 (float32_ref 64x16) [1024, bytes: 4096]
# discriminator/7_full/bias:0 (float32_ref 16) [16, bytes: 64]
# discriminator/out/Matrix:0 (float32_ref 16x1) [16, bytes: 64]
# discriminator/out/bias:0 (float32_ref 1) [1, bytes: 4]
# Total size of variables: 556812
# Total bytes of variables: 2227248
# Add summary for cosmology/mass_histogram_l2log
# Add summary for cosmology/peak_histogram_l2log
# Add summary for cosmology/psd_l2log
# Add summary for cosmology/global_score

# %% [markdown]
# # Train the model

# %%
wgan.train(dataset, resume=resume)
# Out:
# Compute real statistics: cosmology/mass_histogram_l2log
# Compute real statistics: cosmology/peak_histogram_l2log
# Compute real statistics: cosmology/psd_l2log
# Compute real statistics: descriptives/mean_l2
# Compute real statistics: descriptives/var_l2
# Compute real statistics: descriptives/min_l2
# Compute real statistics: descriptives/max_l2
# Compute real statistics: descriptives/kurtosis_l2
# Compute real statistics: descriptives/skewness_l2
# Compute real statistics: descriptives/median_l2
# Compute real statistics: cosmology/mass_histogram_l2log
# Compute real statistics: cosmology/peak_histogram_l2log
# Compute real statistics: cosmology/psd_l2log
# Load weights in the network
#  [*] Reading checkpoints...
# saved_results/WGAN32_2D_patchgan_psd_features_checkpoints/upscale_patch_wgan-27444
# The last checkpoint is found at saved_results/WGAN32_2D_patchgan_psd_features_checkpoints/upscale_patch_wgan-27444
# INFO:tensorflow:Restoring parameters from saved_results/WGAN32_2D_patchgan_psd_features_checkpoints/upscale_patch_wgan-27444
# Start training
#  * Epoch: [ 0] [   7/20480] Counter:27450	( 0.2 min	32.274 examples/sec	0.25 sec/batch)
#    Disc batch loss:-0.41214466	Disc epoch loss:-0.41105422
#    Gen batch loss:-0.06670384	Gen epoch loss:0.21454482
#  * Epoch: [ 0] [  57/20480] Counter:27500	( 0.4 min	39.757 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.41280305	Disc epoch loss:-0.38024413
#    Gen batch loss:0.23035952	Gen epoch loss:0.22244552
#  * Epoch: [ 0] [ 107/20480] Counter:27550	( 0.5 min	39.908 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.27688131	Disc epoch loss:-0.37403949
#    Gen batch loss:0.10552865	Gen epoch loss:0.21984124
#  * Epoch: [ 0] [ 157/20480] Counter:27600	( 0.7 min	39.087 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.35083053	Disc epoch loss:-0.37498927
#    Gen batch loss:0.20369072	Gen epoch loss:0.22132661
# (256, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=8
# Sampling z
# Model saved!
# New lower score at 3.053037354458967
#  * Epoch: [ 0] [ 207/20480] Counter:27650	( 1.5 min	8.499 examples/sec	0.94 sec/batch)
#    Disc batch loss:-0.38979974	Disc epoch loss:-0.37620997
#    Gen batch loss:0.16640922	Gen epoch loss:0.21553524
#  * Epoch: [ 0] [ 257/20480] Counter:27700	( 1.7 min	41.234 examples/sec	0.19 sec/batch)
#    Disc batch loss:-0.38623106	Disc epoch loss:-0.37801030
#    Gen batch loss:0.14066109	Gen epoch loss:0.21068369
#  * Epoch: [ 0] [ 307/20480] Counter:27750	( 1.8 min	42.114 examples/sec	0.19 sec/batch)
#    Disc batch loss:-0.38407892	Disc epoch loss:-0.37634952
#    Gen batch loss:0.33190447	Gen epoch loss:0.20856071
#  * Epoch: [ 0] [ 357/20480] Counter:27800	( 2.0 min	37.427 examples/sec	0.21 sec/batch)
#    Disc batch loss:-0.37058184	Disc epoch loss:-0.37562145
#    Gen batch loss:0.06717449	Gen epoch loss:0.20838187
# (256, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=8
# Sampling z
# Model saved!
# New lower score at 2.630058585902993
#  * Epoch: [ 0] [ 407/20480] Counter:27850	( 2.6 min	11.404 examples/sec	0.70 sec/batch)
#    Disc batch loss:-0.50035417	Disc epoch loss:-0.37606241
#    Gen batch loss:0.28213722	Gen epoch loss:0.21059739
#  * Epoch: [ 0] [ 457/20480] Counter:27900	( 2.7 min	39.731 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.34365001	Disc epoch loss:-0.37617810
#    Gen batch loss:0.09309907	Gen epoch loss:0.21013350
#  * Epoch: [ 0] [ 507/20480] Counter:27950	( 2.9 min	40.464 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.39728948	Disc epoch loss:-0.37546579
#    Gen batch loss:-0.02931681	Gen epoch loss:0.20327894
#  * Epoch: [ 0] [ 557/20480] Counter:28000	( 3.1 min	40.812 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.33450729	Disc epoch loss:-0.37580711
#    Gen batch loss:0.29963177	Gen epoch loss:0.20578785
# (256, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=8
# Sampling z
# Model saved!
#  * Epoch: [ 0] [ 607/20480] Counter:28050	( 3.7 min	11.095 examples/sec	0.72 sec/batch)
#    Disc batch loss:-0.28323442	Disc epoch loss:-0.37583957
#    Gen batch loss:0.06925580	Gen epoch loss:0.20510060
#  * Epoch: [ 0] [ 657/20480] Counter:28100	( 3.8 min	40.392 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.35029715	Disc epoch loss:-0.37603708
#    Gen batch loss:0.27911708	Gen epoch loss:0.20316632
#  * Epoch: [ 0] [ 707/20480] Counter:28150	( 4.0 min	39.749 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.41803992	Disc epoch loss:-0.37593553
#    Gen batch loss:0.13780384	Gen epoch loss:0.20385736
#  * Epoch: [ 0] [ 757/20480] Counter:28200	( 4.2 min	39.378 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.36836028	Disc epoch loss:-0.37567632
#    Gen batch loss:0.04183485	Gen epoch loss:0.20603733
# (256, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=8
# Sampling z
#  * Epoch: [ 0] [ 807/20480] Counter:28250	( 4.8 min	11.372 examples/sec	0.70 sec/batch)
#    Disc batch loss:-0.37084365	Disc epoch loss:-0.37531347
#    Gen batch loss:0.29407415	Gen epoch loss:0.20177981
#  * Epoch: [ 0] [ 857/20480] Counter:28300	( 4.9 min	39.592 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.23354071	Disc epoch loss:-0.37202863
#    Gen batch loss:0.11384368	Gen epoch loss:0.20004920
#  * Epoch: [ 0] [ 907/20480] Counter:28350	( 5.1 min	40.096 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.37760678	Disc epoch loss:-0.37050341
#    Gen batch loss:0.06238375	Gen epoch loss:0.19801651
#  * Epoch: [ 0] [ 957/20480] Counter:28400	( 5.3 min	40.785 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.30194056	Disc epoch loss:-0.37054892
#    Gen batch loss:0.28330937	Gen epoch loss:0.19787519
# (256, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=8
# Sampling z
#  * Epoch: [ 0] [1007/20480] Counter:28450	( 5.8 min	11.685 examples/sec	0.68 sec/batch)
#    Disc batch loss:-0.40831846	Disc epoch loss:-0.37033574
#    Gen batch loss:0.27030045	Gen epoch loss:0.19860392
#  * Epoch: [ 0] [1057/20480] Counter:28500	( 6.0 min	39.901 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.42712438	Disc epoch loss:-0.37049084
#    Gen batch loss:0.39863881	Gen epoch loss:0.19687773
#  * Epoch: [ 0] [1107/20480] Counter:28550	( 6.2 min	40.275 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.36979669	Disc epoch loss:-0.37061759
#    Gen batch loss:0.14139292	Gen epoch loss:0.19602140
#  * Epoch: [ 0] [1157/20480] Counter:28600	( 6.3 min	39.706 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.32707483	Disc epoch loss:-0.37075460
#    Gen batch loss:0.16365673	Gen epoch loss:0.19383874
# (256, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=8
# Sampling z
#  * Epoch: [ 0] [1207/20480] Counter:28650	( 6.9 min	11.381 examples/sec	0.70 sec/batch)
#    Disc batch loss:-0.36201242	Disc epoch loss:-0.37104229
#    Gen batch loss:0.23612180	Gen epoch loss:0.19460719
#  * Epoch: [ 0] [1257/20480] Counter:28700	( 7.1 min	39.794 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.38192955	Disc epoch loss:-0.37048947
#    Gen batch loss:0.21411245	Gen epoch loss:0.19404133
#  * Epoch: [ 0] [1307/20480] Counter:28750	( 7.3 min	39.648 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.32603252	Disc epoch loss:-0.37057880
#    Gen batch loss:0.31533968	Gen epoch loss:0.19306148
#  * Epoch: [ 0] [1357/20480] Counter:28800	( 7.4 min	39.450 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.38239086	Disc epoch loss:-0.37064342
#    Gen batch loss:0.29684541	Gen epoch loss:0.19317007
# (256, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=8
# Sampling z
# Model saved!
# New lower score at 2.3265296789067644
#  * Epoch: [ 0] [1407/20480] Counter:28850	( 8.0 min	11.364 examples/sec	0.70 sec/batch)
#    Disc batch loss:-0.51413357	Disc epoch loss:-0.37106847
#    Gen batch loss:0.18043080	Gen epoch loss:0.19420014
#  * Epoch: [ 0] [1457/20480] Counter:28900	( 8.2 min	40.221 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.43589142	Disc epoch loss:-0.37093875
#    Gen batch loss:0.28713751	Gen epoch loss:0.19349031
#  * Epoch: [ 0] [1507/20480] Counter:28950	( 8.3 min	40.840 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.39837921	Disc epoch loss:-0.37068600
#    Gen batch loss:0.32467395	Gen epoch loss:0.19345370
#  * Epoch: [ 0] [1557/20480] Counter:29000	( 8.5 min	39.558 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.34901571	Disc epoch loss:-0.37084851
#    Gen batch loss:0.29513854	Gen epoch loss:0.19324899
# (256, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=8
# Sampling z
# Model saved!
# New lower score at 1.6241161549507144
# Model saved!
#  * Epoch: [ 0] [1607/20480] Counter:29050	( 9.1 min	11.195 examples/sec	0.71 sec/batch)
#    Disc batch loss:-0.33439553	Disc epoch loss:-0.37085841
#    Gen batch loss:0.30430487	Gen epoch loss:0.19281251
#  * Epoch: [ 0] [1657/20480] Counter:29100	( 9.3 min	39.857 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.33481315	Disc epoch loss:-0.37089193
#    Gen batch loss:0.23412925	Gen epoch loss:0.19212280
#  * Epoch: [ 0] [1707/20480] Counter:29150	( 9.4 min	40.147 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.37038612	Disc epoch loss:-0.37078672
#    Gen batch loss:0.32227856	Gen epoch loss:0.19147987
#  * Epoch: [ 0] [1757/20480] Counter:29200	( 9.6 min	39.974 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.34506020	Disc epoch loss:-0.37064894
#    Gen batch loss:0.07602958	Gen epoch loss:0.19095792
# (256, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=8
# Sampling z
#  * Epoch: [ 0] [1807/20480] Counter:29250	(10.2 min	11.364 examples/sec	0.70 sec/batch)
#    Disc batch loss:-0.36632735	Disc epoch loss:-0.37094775
#    Gen batch loss:0.11107233	Gen epoch loss:0.19105736
#  * Epoch: [ 0] [1857/20480] Counter:29300	(10.4 min	39.522 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.34801993	Disc epoch loss:-0.37131144
#    Gen batch loss:0.31510317	Gen epoch loss:0.19153551
#  * Epoch: [ 0] [1907/20480] Counter:29350	(10.5 min	40.704 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.42723906	Disc epoch loss:-0.37136576
#    Gen batch loss:0.24380869	Gen epoch loss:0.19053773
#  * Epoch: [ 0] [1957/20480] Counter:29400	(10.7 min	39.334 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.28243342	Disc epoch loss:-0.37119094
#    Gen batch loss:0.02320086	Gen epoch loss:0.19080520
# (256, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=8
# Sampling z
#  * Epoch: [ 0] [2007/20480] Counter:29450	(11.3 min	11.570 examples/sec	0.69 sec/batch)
#    Disc batch loss:-0.33333343	Disc epoch loss:-0.37095794
#    Gen batch loss:0.28206107	Gen epoch loss:0.18957256
#  * Epoch: [ 0] [2057/20480] Counter:29500	(11.4 min	39.722 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.40137473	Disc epoch loss:-0.37067553
#    Gen batch loss:0.12734361	Gen epoch loss:0.18946825
#  * Epoch: [ 0] [2107/20480] Counter:29550	(11.6 min	39.885 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.46148530	Disc epoch loss:-0.37035803
#    Gen batch loss:0.31417048	Gen epoch loss:0.18827746
#  * Epoch: [ 0] [2157/20480] Counter:29600	(11.8 min	39.636 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.35594675	Disc epoch loss:-0.37060764
#    Gen batch loss:0.08564463	Gen epoch loss:0.18825820
# (256, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (256, 64, 64, 1)
# ...
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=8
# Sampling z
#  * Epoch: [ 1] [16327/20480] Counter:64250	(212.4 min	11.140 examples/sec	0.72 sec/batch)
#    Disc batch loss:-0.40235963	Disc epoch loss:-0.30819506
#    Gen batch loss:0.23847143	Gen epoch loss:0.15856937
#  * Epoch: [ 1] [16377/20480] Counter:64300	(212.6 min	40.094 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.32358271	Disc epoch loss:-0.30813785
#    Gen batch loss:0.08826977	Gen epoch loss:0.15848685
#  * Epoch: [ 1] [16427/20480] Counter:64350	(212.8 min	40.003 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.22538950	Disc epoch loss:-0.30810691
#    Gen batch loss:0.03379101	Gen epoch loss:0.15847719
#  * Epoch: [ 1] [16477/20480] Counter:64400	(212.9 min	39.619 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.26973128	Disc epoch loss:-0.30807780
#    Gen batch loss:0.03044044	Gen epoch loss:0.15844784
# (256, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=8
# Sampling z
#  * Epoch: [ 1] [16527/20480] Counter:64450	(213.5 min	10.962 examples/sec	0.73 sec/batch)
#    Disc batch loss:-0.29495633	Disc epoch loss:-0.30806975
#    Gen batch loss:0.13862652	Gen epoch loss:0.15841844
#  * Epoch: [ 1] [16577/20480] Counter:64500	(213.7 min	39.704 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.31280324	Disc epoch loss:-0.30805103
#    Gen batch loss:0.06100960	Gen epoch loss:0.15836141
#  * Epoch: [ 1] [16627/20480] Counter:64550	(213.9 min	39.803 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.35342121	Disc epoch loss:-0.30802744
#    Gen batch loss:0.19165750	Gen epoch loss:0.15833438
#  * Epoch: [ 1] [16677/20480] Counter:64600	(214.0 min	40.390 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.34399724	Disc epoch loss:-0.30799242
#    Gen batch loss:0.06714310	Gen epoch loss:0.15828232
# (256, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=7, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=8, row=8
# Sampling z
#  * Epoch: [ 1] [16727/20480] Counter:64650	(214.6 min	10.989 examples/sec	0.73 sec/batch)
#    Disc batch loss:-0.25256878	Disc epoch loss:-0.30792876
#    Gen batch loss:0.02713547	Gen epoch loss:0.15819483
#  * Epoch: [ 1] [16777/20480] Counter:64700	(214.8 min	40.393 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.34020624	Disc epoch loss:-0.30794219
#    Gen batch loss:0.19708306	Gen epoch loss:0.15819583
#  * Epoch: [ 1] [16827/20480] Counter:64750	(215.0 min	39.892 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.26061434	Disc epoch loss:-0.30789105
#    Gen batch loss:0.13648462	Gen epoch loss:0.15816907
#  * Epoch: [ 1] [16877/20480] Counter:64800	(215.1 min	39.753 examples/sec	0.20 sec/batch)
#    Disc batch loss:-0.25067261	Disc epoch loss:-0.30786878
#    Gen batch loss:0.19535287	Gen epoch loss:0.15809311
# (256, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=1, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (256, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z

# %% [markdown]
# # Generate new samples
# To have meaningful statistics, be sure to generate enough samples
# * 2000 : 32 x 32
# * 500 : 64 x 64
# * 200 : 128 x 128

# %%
_, params = utils.test_resume(True, params)
checkpoint = None
wgan = UpscaleGANsystem(CosmoUpscalePatchWGAN, params)
# Out:
# Resume, the training will start from the last iteration!
# Apply attenuation to borders
# Generator
# --------------------------------------------------
#      The input is of size (?, 1024)
#      Reshape to (?, 32, 32, 1)
#      Contenate with latent variables to (?, 32, 32, 5)
#      0 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      1 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      2 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      3 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      4 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      5 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      6 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      7 Inception conv(1x1,3x3,5x5) layer with 1 channels
#          Size of the variables: (?, 32, 32, 1)
#     Costum non linearity: <function relu at 0x7fa921178510>
#      The output is of size (?, 32, 32, 1)
# --------------------------------------------------
#
# Use PSD features
# Discriminator
# --------------------------------------------------
#      The input is of size (?, 64, 64, 3)
#      0 Inception(1x1,3x3,5x5) layer with 64 channels
#          Size of the variables: (?, 32, 32, 64)
#      1 Inception(1x1,3x3,5x5) layer with 64 channels
#          Size of the variables: (?, 16, 16, 64)
#      2 Inception(1x1,3x3,5x5) layer with 32 channels
#          Size of the variables: (?, 8, 8, 32)
#      3 Inception(1x1,3x3,5x5) layer with 16 channels
#          Size of the variables: (?, 8, 8, 16)
#      4 Inception(1x1,3x3,5x5) layer with 8 channels
#          Size of the variables: (?, 8, 8, 8)
#      5 Inception(1x1,3x3,5x5) layer with 2 channels
#          Size of the variables: (?, 8, 8, 2)
#      Reshape to (?, 128)
#      Contenate with psd_features to (?, 585)
#      6 Full layer with 64 outputs
#          Size of the variables: (?, 64)
#      7 Full layer with 16 outputs
#          Size of the variables: (?, 16)
#      8 Full layer with 1 outputs
#      The output is of size (?, 1)
# --------------------------------------------------
#
#  Wasserstein loss with gamma_gp=10
#  Using gradients penalty
# Add summary for descriptives/mean_real
# Add summary for descriptives/var_real
# Add summary for descriptives/min_real
# Add summary for descriptives/max_real
# Add summary for descriptives/kurtosis_real
# Add summary for descriptives/skewness_real
# Add summary for descriptives/median_real
# Add summary for descriptives/mean_fake
# Add summary for descriptives/var_fake
# Add summary for descriptives/min_fake
# Add summary for descriptives/max_fake
# Add summary for descriptives/kurtosis_fake
# Add summary for descriptives/skewness_fake
# Add summary for descriptives/median_fake
# Add summary for descriptives/mean_l2
# Add summary for descriptives/var_l2
# Add summary for descriptives/min_l2
# Add summary for descriptives/max_l2
# Add summary for descriptives/kurtosis_l2
# Add summary for descriptives/skewness_l2
# Add summary for descriptives/median_l2
# Add summary for cosmology/mass_histogram_l2log
# Add summary for cosmology/peak_histogram_l2log
# Add summary for cosmology/psd_l2log
# Add summary for cosmology/global_score
#
# Build the optimizers:
#  * discriminator
# kwargs: {}
# learning_rate: 3.0e-05
# optimizer: rmsprop
#
#  * generator
# kwargs: {}
# learning_rate: 3.0e-05
# optimizer: rmsprop
#
# ---------
# Variables: name (type shape) [size]
# ---------
# generator/0_conv_1_by_1/w:0 (float32_ref 1x1x5x32) [160, bytes: 640]
# generator/0_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/0_conv_3_by_3/w:0 (float32_ref 3x3x5x32) [1440, bytes: 5760]
# generator/0_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/0_conv_5_by_5/w:0 (float32_ref 5x5x5x32) [4000, bytes: 16000]
# generator/0_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/0_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/0_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/1_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/1_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/1_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/1_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/2_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/2_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/2_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/2_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/3_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/3_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/3_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/3_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/4_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/4_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/4_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/4_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/5_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/5_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/5_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/5_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/6_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/6_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/6_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/6_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/7_conv_1_by_1/w:0 (float32_ref 1x1x32x1) [32, bytes: 128]
# generator/7_conv_1_by_1/biases:0 (float32_ref 1) [1, bytes: 4]
# generator/7_conv_3_by_3/w:0 (float32_ref 3x3x32x1) [288, bytes: 1152]
# generator/7_conv_3_by_3/biases:0 (float32_ref 1) [1, bytes: 4]
# generator/7_conv_5_by_5/w:0 (float32_ref 5x5x32x1) [800, bytes: 3200]
# generator/7_conv_5_by_5/biases:0 (float32_ref 1) [1, bytes: 4]
# generator/7_conv_1_by_1_merge/w:0 (float32_ref 1x1x3x1) [3, bytes: 12]
# generator/7_conv_1_by_1_merge/biases:0 (float32_ref 1) [1, bytes: 4]
# discriminator/0_conv_1_by_1/w:0 (float32_ref 1x1x3x64) [192, bytes: 768]
# discriminator/0_conv_1_by_1/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/0_conv_3_by_3/w:0 (float32_ref 3x3x3x64) [1728, bytes: 6912]
# discriminator/0_conv_3_by_3/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/0_conv_5_by_5/w:0 (float32_ref 5x5x3x64) [4800, bytes: 19200]
# discriminator/0_conv_5_by_5/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/0_conv_1_by_1_merge/w:0 (float32_ref 1x1x192x64) [12288, bytes: 49152]
# discriminator/0_conv_1_by_1_merge/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_1_by_1/w:0 (float32_ref 1x1x64x64) [4096, bytes: 16384]
# discriminator/1_conv_1_by_1/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_3_by_3/w:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# discriminator/1_conv_3_by_3/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_5_by_5/w:0 (float32_ref 5x5x64x64) [102400, bytes: 409600]
# discriminator/1_conv_5_by_5/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_1_by_1_merge/w:0 (float32_ref 1x1x192x64) [12288, bytes: 49152]
# discriminator/1_conv_1_by_1_merge/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/2_conv_1_by_1/w:0 (float32_ref 1x1x64x32) [2048, bytes: 8192]
# discriminator/2_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/2_conv_3_by_3/w:0 (float32_ref 3x3x64x32) [18432, bytes: 73728]
# discriminator/2_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/2_conv_5_by_5/w:0 (float32_ref 5x5x64x32) [51200, bytes: 204800]
# discriminator/2_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/2_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# discriminator/2_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/3_conv_1_by_1/w:0 (float32_ref 1x1x32x16) [512, bytes: 2048]
# discriminator/3_conv_1_by_1/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/3_conv_3_by_3/w:0 (float32_ref 3x3x32x16) [4608, bytes: 18432]
# discriminator/3_conv_3_by_3/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/3_conv_5_by_5/w:0 (float32_ref 5x5x32x16) [12800, bytes: 51200]
# discriminator/3_conv_5_by_5/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/3_conv_1_by_1_merge/w:0 (float32_ref 1x1x48x16) [768, bytes: 3072]
# discriminator/3_conv_1_by_1_merge/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/4_conv_1_by_1/w:0 (float32_ref 1x1x16x8) [128, bytes: 512]
# discriminator/4_conv_1_by_1/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/4_conv_3_by_3/w:0 (float32_ref 3x3x16x8) [1152, bytes: 4608]
# discriminator/4_conv_3_by_3/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/4_conv_5_by_5/w:0 (float32_ref 5x5x16x8) [3200, bytes: 12800]
# discriminator/4_conv_5_by_5/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/4_conv_1_by_1_merge/w:0 (float32_ref 1x1x24x8) [192, bytes: 768]
# discriminator/4_conv_1_by_1_merge/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/5_conv_1_by_1/w:0 (float32_ref 1x1x8x2) [16, bytes: 64]
# discriminator/5_conv_1_by_1/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/5_conv_3_by_3/w:0 (float32_ref 3x3x8x2) [144, bytes: 576]
# discriminator/5_conv_3_by_3/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/5_conv_5_by_5/w:0 (float32_ref 5x5x8x2) [400, bytes: 1600]
# discriminator/5_conv_5_by_5/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/5_conv_1_by_1_merge/w:0 (float32_ref 1x1x6x2) [12, bytes: 48]
# discriminator/5_conv_1_by_1_merge/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/6_full/Matrix:0 (float32_ref 585x64) [37440, bytes: 149760]
# discriminator/6_full/bias:0 (float32_ref 64) [64, bytes: 256]
# discriminator/7_full/Matrix:0 (float32_ref 64x16) [1024, bytes: 4096]
# discriminator/7_full/bias:0 (float32_ref 16) [16, bytes: 64]
# discriminator/out/Matrix:0 (float32_ref 16x1) [16, bytes: 64]
# discriminator/out/bias:0 (float32_ref 1) [1, bytes: 4]
# Total size of variables: 556812
# Total bytes of variables: 2227248
# Add summary for cosmology/mass_histogram_l2log
# Add summary for cosmology/peak_histogram_l2log
# Add summary for cosmology/psd_l2log
# Add summary for cosmology/global_score

# %%
from gantools.blocks import downsample

# %%
Nsample = 512
X_real = dataset._X[:Nsample]
X_down = downsample(X_real, 4)

# %%
X_fake = wgan.upscale_image(small=np.expand_dims(X_down, axis=3), checkpoint=checkpoint)
# Out:
#  [*] Reading checkpoints...
# saved_results/WGAN32_2D_patchgan_psd_features_checkpoints/upscale_patch_wgan-27444
# The last checkpoint is found at saved_results/WGAN32_2D_patchgan_psd_features_checkpoints/upscale_patch_wgan-27444
# INFO:tensorflow:Restoring parameters from saved_results/WGAN32_2D_patchgan_psd_features_checkpoints/upscale_patch_wgan-27444
# Checkpoint successfully loaded!
# (512, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=1, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=1, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=1, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=1, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=1, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=1, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=1, row=8
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=8
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=8
# Sampling z

# %% [markdown]
# Display a few fake samples

# %%
clim = (0,3)
plt.figure(figsize=(30,10))
plt.subplot(131)
plot.draw_images(X_fake,nx=1,ny=1,vmin=clim[0], vmax=clim[1], cmap = plt.cm.plasma);

plt.title("Fake samples");
plt.subplot(132)
plot.draw_images(X_real,nx=1,ny=1,vmin=clim[0], vmax=clim[1], cmap = plt.cm.plasma);
plt.title("Real samples");
plt.subplot(133)
plot.draw_images(X_down,nx=1,ny=1,vmin=clim[0], vmax=clim[1], cmap = plt.cm.plasma);
plt.title("Down samples");

# %% [markdown]
# # Evaluation of the sample quality

# %%
# Before computing the statistics, we need to invert the mapping
raw_images = backward(X_real)
gen_sample_raw = backward(X_fake)

# %%
logel2, l2, logel1, l1 = evaluation.compute_and_plot_psd(raw_images, gen_sample_raw)
# Out:
# Log l2 PSD loss: 1.7582954632390713
# L2 PSD loss: 408.86290782417854
# Log l1 PSD loss: 1.208350545799954
# L1 PSD loss: 15.436538289258902

# %%
logel2, l2, logel1, l1 = evaluation.compute_and_plot_peak_cout(raw_images, gen_sample_raw)
# Out:
# Log l2 Peak Count loss: 0.02525503614475489
# L2 Peak Count loss: 3.4896744278842604e-06
# Log l1 Peak Count loss: 0.12494438768157234
# L1 Peak Count loss: 0.0013329091220496863

# %%
logel2, l2, logel1, l1 = evaluation.compute_and_plot_mass_hist(raw_images, gen_sample_raw)
# Out:
# Log l2 Mass histogram loss: 0.28526366673807646
# L2 Peak Mass histogram: 6.145801521011407e-05
# Log l1 Mass histogram loss: 0.2758759524378814
# L1 Mass histogram loss: 0.004133701324462891
