# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# import sys
# sys.path.insert(0, '../')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"


import numpy as np
import tensorflow as tf

from gantools import data
from gantools import utils
from gantools import plot
from gantools.model import CosmoWGAN, WGAN, LapWGAN, UpscalePatchWGAN
from gantools.gansystem import GANsystem, UpscaleGANsystem
from gantools.data import fmap
from gantools import evaluation
import functools
import matplotlib.pyplot as plt
from copy import deepcopy

# %% [markdown]
# # Parameters

# %%
ns = 32 # Resolution of the image
try_resume = True # Try to resume previous simulation
Mpch = 350 # Type of dataset (select 70 or 350)

# Do not change these for now
# shift = 3
# c = 40000
# forward = functools.partial(fmap.stat_forward, shift=shift, c=c)
# backward = functools.partial(fmap.stat_backward, shift=shift, c=c)

forward = fmap.stat_forward
backward = fmap.stat_backward

# %% [markdown]
# # Data handling

# %% [markdown]
# Load the data

# %%
dataset = data.load.load_nbody_dataset(nsamples=10, spix=ns, Mpch=Mpch, forward_map=forward, patch=True, is_3d=False)
# Out:
# Select 10 samples out of 30.
# images shape =  (10, 256, 256, 256)

# %%
# The dataset can return an iterator.
it = dataset.iter(10)
print(next(it).shape)
del it
# Out:
# (10, 32, 32, 4)

# %%
# Get all the data
X = dataset.get_all_data()[:,:,:,0].flatten()

# %%
# Check that the backward maps invert the forward map.
# assert(np.sum(np.abs(forward(backward(X))-X))< 5)
# # For debugging
# np.sum(np.abs(forward(backward(X))-X))
# forward(backward(X))-X
# x = np.arange(1e4)
# plt.plot(x, backward(forward(x))-x)

# %%
np.sum(np.abs(forward(backward(X))-X))
# Out:
# 2.0770688

# %% [markdown]
# Display the histogram of the pixel densities after the forward map

# %%
plt.hist(X, 100)
print('min: {}'.format(np.min(X)))
print('max: {}'.format(np.max(X)))
plt.yscale('log')
# Out:
# min: 0.0
# max: 6.077099323272705

# %%
# to free some memory
del X

# %% [markdown]
# Let us plot 16 images

# %%
plt.figure(figsize=(15,15))
plot.draw_images(dataset.get_samples(N=16)[:,:,:,0],nx=4,ny=4);
plt.title("Real samples")
# Out:
# Text(0.5,1,'Real samples')

# %% [markdown]
# # Define parameters for the WGAN

# %%
time_str = '2D_patchgan_up_weights'
global_path = 'saved_results'

name = 'WGAN{}'.format(ns) + '_' + time_str

# %% [markdown]
# ## Parameters

# %%
bn = False

md=32

params_discriminator = dict()

params_discriminator['stride'] = [2, 2, 2, 1, 1, 1]
params_discriminator['nfilter'] = [2*md, 2*md, md, md//2, md//4,2]
params_discriminator['shape'] = [[4, 4],[4, 4], [4, 4],[4, 4], [4, 4], [4, 4]]
params_discriminator['batch_norm'] = [bn, bn, bn, bn, bn, bn]
params_discriminator['full'] = [64, 16]
params_discriminator['minibatch_reg'] = False
params_discriminator['summary'] = True
params_discriminator['data_size'] = 2
params_discriminator['inception'] = True
params_discriminator['spectral_norm'] = False

params_generator = dict()
params_generator['stride'] = [1, 1, 1, 1, 1, 1, 1, 1]
params_generator['latent_dim'] = 32*32
params_generator['latent_dim_split'] = None
params_generator['in_conv_shape'] =[32, 32]
params_generator['nfilter'] = [md, md, md, md, md, md, md, 1]
params_generator['shape'] = [[4, 4],[4, 4], [4, 4],[4, 4], [4, 4], [4, 4]]
params_generator['batch_norm'] = [bn, bn, bn, bn,bn, bn, bn]
params_generator['full'] = []
params_generator['summary'] = True
params_generator['non_lin'] = tf.nn.relu
params_generator['data_size'] = 2
params_generator['inception'] = True
params_generator['spectral_norm'] = False
params_generator['use_Xdown'] = False
params_generator['weights_border'] = True


# Optimization parameters inspired from 'Self-Attention Generative Adversarial Networks'
# - Spectral normalization GEN DISC
# - Batch norm GEN
# - TTUR ('GANs Trained by a Two Time-Scale Update Rule Converge to a Local Nash Equilibrium')
# - ADAM  beta1=0 beta2=0.9, disc lr 0.0004, gen lr 0.0001
# - Hinge loss
# Parameters are similar to the ones in those papers...
# - 'PROGRESSIVE GROWING OF GANS FOR IMPROVED QUALITY, STABILITY, AND VARIATION'
# - 'LARGE SCALE GAN TRAINING FOR HIGH FIDELITY NATURAL IMAGE SYNTHESIS'
# - 'CGANS WITH PROJECTION DISCRIMINATOR'

params_optimization = dict()
params_optimization['batch_size'] = 8
params_optimization['epoch'] = 100
params_optimization['n_critic'] = 5
# params_optimization['generator'] = dict()
# params_optimization['generator']['optimizer'] = 'adam'
# params_optimization['generator']['kwargs'] = {'beta1':0, 'beta2':0.9}
# params_optimization['generator']['learning_rate'] = 0.0004
# params_optimization['discriminator'] = dict()
# params_optimization['discriminator']['optimizer'] = 'adam'
# params_optimization['discriminator']['kwargs'] = {'beta1':0, 'beta2':0.9}
# params_optimization['discriminator']['learning_rate'] = 0.0001

# Cosmology parameters
params_cosmology = dict()
params_cosmology['forward_map'] = forward
params_cosmology['backward_map'] = backward


# all parameters
params = dict()
params['net'] = dict() # All the parameters for the model
params['net']['generator'] = params_generator
params['net']['discriminator'] = params_discriminator
params['net']['cosmology'] = params_cosmology # Parameters for the cosmological summaries
params['net']['prior_distribution'] = 'gaussian'
params['net']['shape'] = [ns, ns, 4] # Shape of the image
params['net']['loss_type'] = 'normalized_wasserstein' # loss ('hinge' or 'wasserstein')
params['net']['gamma_gp'] = 10 # Gradient penalty
params['net']['upscaling'] = 4 

params['optimization'] = params_optimization
params['summary_every'] = 200 # Tensorboard summaries every ** iterations
params['print_every'] = 50 # Console summaries every ** iterations
params['save_every'] = 1000 # Save the model every ** iterations
params['summary_dir'] = os.path.join(global_path, name +'_summary/')
params['save_dir'] = os.path.join(global_path, name + '_checkpoints/')
params['Nstats'] = 1000
params['Nstats_cubes'] = 30

# %%
resume, params = utils.test_resume(try_resume, params)
# If a model is reloaded and some parameters have to be changed, then it should be done here.
# For example, setting the number of epoch to 5 would be:
params['optimization']['epoch'] = 5
# Out:
# Resume, the training will start from the last iteration!

# %% [markdown]
# # Build the model

# %%
class CosmoUpscalePatchWGAN(UpscalePatchWGAN, CosmoWGAN):
    pass
wgan = GANsystem(CosmoUpscalePatchWGAN, params)
# Out:
# Apply attenuation to borders
# Generator
# --------------------------------------------------
#      The input is of size (?, 1024)
#      Reshape to (?, 32, 32, 1)
#      Contenate with latent variables to (?, 32, 32, 5)
#      0 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      1 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      2 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      3 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      4 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      5 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      6 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      7 Inception conv(1x1,3x3,5x5) layer with 1 channels
#          Size of the variables: (?, 32, 32, 1)
#     Costum non linearity: <function relu at 0x7fd5c30ed0d0>
#      The output is of size (?, 32, 32, 1)
# --------------------------------------------------
#
# Discriminator
# --------------------------------------------------
#      The input is of size (?, 64, 64, 3)
#      0 Inception(1x1,3x3,5x5) layer with 64 channels
#          Size of the variables: (?, 32, 32, 64)
#      1 Inception(1x1,3x3,5x5) layer with 64 channels
#          Size of the variables: (?, 16, 16, 64)
#      2 Inception(1x1,3x3,5x5) layer with 32 channels
#          Size of the variables: (?, 8, 8, 32)
#      3 Inception(1x1,3x3,5x5) layer with 16 channels
#          Size of the variables: (?, 8, 8, 16)
#      4 Inception(1x1,3x3,5x5) layer with 8 channels
#          Size of the variables: (?, 8, 8, 8)
#      5 Inception(1x1,3x3,5x5) layer with 2 channels
#          Size of the variables: (?, 8, 8, 2)
#      Reshape to (?, 128)
#      6 Full layer with 64 outputs
#          Size of the variables: (?, 64)
#      7 Full layer with 16 outputs
#          Size of the variables: (?, 16)
#      8 Full layer with 1 outputs
#      The output is of size (?, 1)
# --------------------------------------------------
#
#  Wasserstein loss with gamma_gp=10
#  Using gradients penalty
# Add summary for descriptives/mean_real
# Add summary for descriptives/var_real
# Add summary for descriptives/min_real
# Add summary for descriptives/max_real
# Add summary for descriptives/kurtosis_real
# Add summary for descriptives/skewness_real
# Add summary for descriptives/median_real
# Add summary for descriptives/mean_fake
# Add summary for descriptives/var_fake
# Add summary for descriptives/min_fake
# Add summary for descriptives/max_fake
# Add summary for descriptives/kurtosis_fake
# Add summary for descriptives/skewness_fake
# Add summary for descriptives/median_fake
# Add summary for descriptives/mean_l2
# Add summary for descriptives/var_l2
# Add summary for descriptives/min_l2
# Add summary for descriptives/max_l2
# Add summary for descriptives/kurtosis_l2
# Add summary for descriptives/skewness_l2
# Add summary for descriptives/median_l2
# Add summary for cosmology/mass_histogram_l2log
# Add summary for cosmology/peak_histogram_l2log
# Add summary for cosmology/psd_l2log
# Add summary for cosmology/global_score
#
# Build the optimizers:
#  * discriminator
# kwargs: {}
# learning_rate: 3.0e-05
# optimizer: rmsprop
#
#  * generator
# kwargs: {}
# learning_rate: 3.0e-05
# optimizer: rmsprop
#
# ---------
# Variables: name (type shape) [size]
# ---------
# generator/0_conv_1_by_1/w:0 (float32_ref 1x1x5x32) [160, bytes: 640]
# generator/0_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/0_conv_3_by_3/w:0 (float32_ref 3x3x5x32) [1440, bytes: 5760]
# generator/0_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/0_conv_5_by_5/w:0 (float32_ref 5x5x5x32) [4000, bytes: 16000]
# generator/0_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/0_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/0_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/1_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/1_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/1_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/1_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/2_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/2_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/2_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/2_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/3_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/3_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/3_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/3_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/4_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/4_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/4_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/4_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/5_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/5_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/5_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/5_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/6_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/6_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/6_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/6_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/7_conv_1_by_1/w:0 (float32_ref 1x1x32x1) [32, bytes: 128]
# generator/7_conv_1_by_1/biases:0 (float32_ref 1) [1, bytes: 4]
# generator/7_conv_3_by_3/w:0 (float32_ref 3x3x32x1) [288, bytes: 1152]
# generator/7_conv_3_by_3/biases:0 (float32_ref 1) [1, bytes: 4]
# generator/7_conv_5_by_5/w:0 (float32_ref 5x5x32x1) [800, bytes: 3200]
# generator/7_conv_5_by_5/biases:0 (float32_ref 1) [1, bytes: 4]
# generator/7_conv_1_by_1_merge/w:0 (float32_ref 1x1x3x1) [3, bytes: 12]
# generator/7_conv_1_by_1_merge/biases:0 (float32_ref 1) [1, bytes: 4]
# discriminator/0_conv_1_by_1/w:0 (float32_ref 1x1x3x64) [192, bytes: 768]
# discriminator/0_conv_1_by_1/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/0_conv_3_by_3/w:0 (float32_ref 3x3x3x64) [1728, bytes: 6912]
# discriminator/0_conv_3_by_3/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/0_conv_5_by_5/w:0 (float32_ref 5x5x3x64) [4800, bytes: 19200]
# discriminator/0_conv_5_by_5/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/0_conv_1_by_1_merge/w:0 (float32_ref 1x1x192x64) [12288, bytes: 49152]
# discriminator/0_conv_1_by_1_merge/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_1_by_1/w:0 (float32_ref 1x1x64x64) [4096, bytes: 16384]
# discriminator/1_conv_1_by_1/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_3_by_3/w:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# discriminator/1_conv_3_by_3/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_5_by_5/w:0 (float32_ref 5x5x64x64) [102400, bytes: 409600]
# discriminator/1_conv_5_by_5/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_1_by_1_merge/w:0 (float32_ref 1x1x192x64) [12288, bytes: 49152]
# discriminator/1_conv_1_by_1_merge/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/2_conv_1_by_1/w:0 (float32_ref 1x1x64x32) [2048, bytes: 8192]
# discriminator/2_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/2_conv_3_by_3/w:0 (float32_ref 3x3x64x32) [18432, bytes: 73728]
# discriminator/2_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/2_conv_5_by_5/w:0 (float32_ref 5x5x64x32) [51200, bytes: 204800]
# discriminator/2_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/2_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# discriminator/2_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/3_conv_1_by_1/w:0 (float32_ref 1x1x32x16) [512, bytes: 2048]
# discriminator/3_conv_1_by_1/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/3_conv_3_by_3/w:0 (float32_ref 3x3x32x16) [4608, bytes: 18432]
# discriminator/3_conv_3_by_3/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/3_conv_5_by_5/w:0 (float32_ref 5x5x32x16) [12800, bytes: 51200]
# discriminator/3_conv_5_by_5/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/3_conv_1_by_1_merge/w:0 (float32_ref 1x1x48x16) [768, bytes: 3072]
# discriminator/3_conv_1_by_1_merge/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/4_conv_1_by_1/w:0 (float32_ref 1x1x16x8) [128, bytes: 512]
# discriminator/4_conv_1_by_1/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/4_conv_3_by_3/w:0 (float32_ref 3x3x16x8) [1152, bytes: 4608]
# discriminator/4_conv_3_by_3/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/4_conv_5_by_5/w:0 (float32_ref 5x5x16x8) [3200, bytes: 12800]
# discriminator/4_conv_5_by_5/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/4_conv_1_by_1_merge/w:0 (float32_ref 1x1x24x8) [192, bytes: 768]
# discriminator/4_conv_1_by_1_merge/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/5_conv_1_by_1/w:0 (float32_ref 1x1x8x2) [16, bytes: 64]
# discriminator/5_conv_1_by_1/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/5_conv_3_by_3/w:0 (float32_ref 3x3x8x2) [144, bytes: 576]
# discriminator/5_conv_3_by_3/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/5_conv_5_by_5/w:0 (float32_ref 5x5x8x2) [400, bytes: 1600]
# discriminator/5_conv_5_by_5/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/5_conv_1_by_1_merge/w:0 (float32_ref 1x1x6x2) [12, bytes: 48]
# discriminator/5_conv_1_by_1_merge/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/6_full/Matrix:0 (float32_ref 128x64) [8192, bytes: 32768]
# discriminator/6_full/bias:0 (float32_ref 64) [64, bytes: 256]
# discriminator/7_full/Matrix:0 (float32_ref 64x16) [1024, bytes: 4096]
# discriminator/7_full/bias:0 (float32_ref 16) [16, bytes: 64]
# discriminator/out/Matrix:0 (float32_ref 16x1) [16, bytes: 64]
# discriminator/out/bias:0 (float32_ref 1) [1, bytes: 4]
# Total size of variables: 527564
# Total bytes of variables: 2110256

# %% [markdown]
# # Train the model

# %%
wgan.train(dataset, resume=resume)
# Out:
# Compute real statistics: descriptives/mean_l2
# Compute real statistics: descriptives/var_l2
# Compute real statistics: descriptives/min_l2
# Compute real statistics: descriptives/max_l2
# Compute real statistics: descriptives/kurtosis_l2
# Compute real statistics: descriptives/skewness_l2
# Compute real statistics: descriptives/median_l2
# Compute real statistics: cosmology/mass_histogram_l2log
# Compute real statistics: cosmology/peak_histogram_l2log
# Compute real statistics: cosmology/psd_l2log
# Load weights in the network
#  [*] Reading checkpoints...
# saved_results/WGAN32_2D_patchgan_up_weights_checkpoints/upscale_patch_wgan-14181
# The last checkpoint is found at saved_results/WGAN32_2D_patchgan_up_weights_checkpoints/upscale_patch_wgan-14181
# INFO:tensorflow:Restoring parameters from saved_results/WGAN32_2D_patchgan_up_weights_checkpoints/upscale_patch_wgan-14181
# Start training
#  * Epoch: [ 0] [  20/20480] Counter:14200	( 0.2 min	27.327 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.41755489	Disc epoch loss:-0.47854791
#    Gen batch loss:0.13210718	Gen epoch loss:0.30083969
#  * Epoch: [ 0] [  70/20480] Counter:14250	( 0.7 min	15.469 examples/sec	0.52 sec/batch)
#    Disc batch loss:-0.47590160	Disc epoch loss:-0.47317524
#    Gen batch loss:0.40061894	Gen epoch loss:0.24362140
#  * Epoch: [ 0] [ 120/20480] Counter:14300	( 0.8 min	45.285 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.49759677	Disc epoch loss:-0.47672573
#    Gen batch loss:0.21721858	Gen epoch loss:0.23543213
#  * Epoch: [ 0] [ 170/20480] Counter:14350	( 1.0 min	45.043 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.52146840	Disc epoch loss:-0.47562164
#    Gen batch loss:0.32024008	Gen epoch loss:0.22984950
#  * Epoch: [ 0] [ 220/20480] Counter:14400	( 1.1 min	45.198 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.42086110	Disc epoch loss:-0.47505002
#    Gen batch loss:0.18735062	Gen epoch loss:0.23543075
#  * Epoch: [ 0] [ 270/20480] Counter:14450	( 1.4 min	27.642 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.40842652	Disc epoch loss:-0.47405962
#    Gen batch loss:0.28197393	Gen epoch loss:0.24184375
#  * Epoch: [ 0] [ 320/20480] Counter:14500	( 1.5 min	44.458 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.43557292	Disc epoch loss:-0.47575878
#    Gen batch loss:0.30604374	Gen epoch loss:0.24738399
#  * Epoch: [ 0] [ 370/20480] Counter:14550	( 1.7 min	44.143 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.48567635	Disc epoch loss:-0.47423163
#    Gen batch loss:0.08321434	Gen epoch loss:0.24565635
#  * Epoch: [ 0] [ 420/20480] Counter:14600	( 1.8 min	44.412 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.48395881	Disc epoch loss:-0.47504295
#    Gen batch loss:0.17248115	Gen epoch loss:0.23976164
#  * Epoch: [ 0] [ 470/20480] Counter:14650	( 2.1 min	27.407 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.50130069	Disc epoch loss:-0.47344539
#    Gen batch loss:0.20144477	Gen epoch loss:0.23448427
#  * Epoch: [ 0] [ 520/20480] Counter:14700	( 2.2 min	43.975 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.46848264	Disc epoch loss:-0.47262447
#    Gen batch loss:0.26745653	Gen epoch loss:0.23715438
#  * Epoch: [ 0] [ 570/20480] Counter:14750	( 2.4 min	44.276 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.43456364	Disc epoch loss:-0.47173893
#    Gen batch loss:0.25189278	Gen epoch loss:0.23901560
#  * Epoch: [ 0] [ 620/20480] Counter:14800	( 2.5 min	44.414 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.49948248	Disc epoch loss:-0.47241356
#    Gen batch loss:0.37832797	Gen epoch loss:0.23951914
#  * Epoch: [ 0] [ 670/20480] Counter:14850	( 2.8 min	26.363 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.37620983	Disc epoch loss:-0.47212601
#    Gen batch loss:0.24134859	Gen epoch loss:0.24096378
#  * Epoch: [ 0] [ 720/20480] Counter:14900	( 2.9 min	44.413 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.46379879	Disc epoch loss:-0.47221489
#    Gen batch loss:0.33439824	Gen epoch loss:0.23852227
#  * Epoch: [ 0] [ 770/20480] Counter:14950	( 3.1 min	44.111 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.41937187	Disc epoch loss:-0.47201698
#    Gen batch loss:0.28903773	Gen epoch loss:0.24059474
#  * Epoch: [ 0] [ 820/20480] Counter:15000	( 3.2 min	44.311 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.37008634	Disc epoch loss:-0.47178237
#    Gen batch loss:0.13923034	Gen epoch loss:0.23947983
# Model saved!
#  * Epoch: [ 0] [ 870/20480] Counter:15050	( 3.5 min	26.345 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.44229952	Disc epoch loss:-0.47197058
#    Gen batch loss:0.15100026	Gen epoch loss:0.23726481
#  * Epoch: [ 0] [ 920/20480] Counter:15100	( 3.6 min	44.506 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.50744140	Disc epoch loss:-0.47177420
#    Gen batch loss:0.11889891	Gen epoch loss:0.23778057
#  * Epoch: [ 0] [ 970/20480] Counter:15150	( 3.8 min	43.961 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.56952208	Disc epoch loss:-0.47161600
#    Gen batch loss:0.30930406	Gen epoch loss:0.23589466
#  * Epoch: [ 0] [1020/20480] Counter:15200	( 3.9 min	44.207 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.41101730	Disc epoch loss:-0.47106120
#    Gen batch loss:0.13119023	Gen epoch loss:0.23689130
#  * Epoch: [ 0] [1070/20480] Counter:15250	( 4.2 min	27.344 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.43596095	Disc epoch loss:-0.47097835
#    Gen batch loss:0.22355688	Gen epoch loss:0.23776781
#  * Epoch: [ 0] [1120/20480] Counter:15300	( 4.3 min	44.584 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.46908176	Disc epoch loss:-0.47063507
#    Gen batch loss:0.22759862	Gen epoch loss:0.23698763
#  * Epoch: [ 0] [1170/20480] Counter:15350	( 4.5 min	44.284 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.46015552	Disc epoch loss:-0.46992944
#    Gen batch loss:0.08295429	Gen epoch loss:0.23534578
#  * Epoch: [ 0] [1220/20480] Counter:15400	( 4.6 min	44.473 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.45649713	Disc epoch loss:-0.46932793
#    Gen batch loss:0.20972385	Gen epoch loss:0.23275411
#  * Epoch: [ 0] [1270/20480] Counter:15450	( 4.9 min	26.933 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.43350178	Disc epoch loss:-0.46875341
#    Gen batch loss:0.26113141	Gen epoch loss:0.23457884
#  * Epoch: [ 0] [1320/20480] Counter:15500	( 5.0 min	44.648 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.48613241	Disc epoch loss:-0.46852708
#    Gen batch loss:0.25321704	Gen epoch loss:0.23378562
#  * Epoch: [ 0] [1370/20480] Counter:15550	( 5.2 min	43.812 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.36291146	Disc epoch loss:-0.46803145
#    Gen batch loss:0.12199719	Gen epoch loss:0.23353692
#  * Epoch: [ 0] [1420/20480] Counter:15600	( 5.3 min	44.217 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.39225093	Disc epoch loss:-0.46771132
#    Gen batch loss:0.14564282	Gen epoch loss:0.23389667
#  * Epoch: [ 0] [1470/20480] Counter:15650	( 5.6 min	27.131 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.51178497	Disc epoch loss:-0.46747139
#    Gen batch loss:0.21743168	Gen epoch loss:0.23298645
#  * Epoch: [ 0] [1520/20480] Counter:15700	( 5.7 min	43.963 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.43711975	Disc epoch loss:-0.46718682
#    Gen batch loss:0.19609065	Gen epoch loss:0.23337739
#  * Epoch: [ 0] [1570/20480] Counter:15750	( 5.9 min	44.312 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.54301506	Disc epoch loss:-0.46663877
#    Gen batch loss:0.20305756	Gen epoch loss:0.23265606
#  * Epoch: [ 0] [1620/20480] Counter:15800	( 6.0 min	44.771 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.48242697	Disc epoch loss:-0.46637828
#    Gen batch loss:0.21700765	Gen epoch loss:0.23135278
#  * Epoch: [ 0] [1670/20480] Counter:15850	( 6.3 min	27.111 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.38538089	Disc epoch loss:-0.46603218
#    Gen batch loss:0.31792957	Gen epoch loss:0.23057845
#  * Epoch: [ 0] [1720/20480] Counter:15900	( 6.4 min	44.379 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.36486074	Disc epoch loss:-0.46547198
#    Gen batch loss:0.33680713	Gen epoch loss:0.23022368
#  * Epoch: [ 0] [1770/20480] Counter:15950	( 6.6 min	43.903 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.53176570	Disc epoch loss:-0.46489905
#    Gen batch loss:0.13959767	Gen epoch loss:0.22970095
#  * Epoch: [ 0] [1820/20480] Counter:16000	( 6.7 min	44.153 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.39681217	Disc epoch loss:-0.46453253
#    Gen batch loss:0.07836579	Gen epoch loss:0.22903526
# Model saved!
#  * Epoch: [ 0] [1870/20480] Counter:16050	( 7.0 min	25.148 examples/sec	0.32 sec/batch)
#    Disc batch loss:-0.50294554	Disc epoch loss:-0.46417975
#    Gen batch loss:0.34929085	Gen epoch loss:0.22924881
#  * Epoch: [ 0] [1920/20480] Counter:16100	( 7.1 min	44.559 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.44059825	Disc epoch loss:-0.46383422
#    Gen batch loss:0.19670598	Gen epoch loss:0.23021095
#  * Epoch: [ 0] [1970/20480] Counter:16150	( 7.3 min	44.122 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.42225415	Disc epoch loss:-0.46337351
#    Gen batch loss:0.25784096	Gen epoch loss:0.23022418
#  * Epoch: [ 0] [2020/20480] Counter:16200	( 7.4 min	44.266 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.38104612	Disc epoch loss:-0.46310381
#    Gen batch loss:0.19944347	Gen epoch loss:0.23016992
#  * Epoch: [ 0] [2070/20480] Counter:16250	( 7.7 min	27.046 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.42227685	Disc epoch loss:-0.46279872
#    Gen batch loss:0.37846443	Gen epoch loss:0.22992783
#  * Epoch: [ 0] [2120/20480] Counter:16300	( 7.8 min	44.319 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.51273513	Disc epoch loss:-0.46223667
#    Gen batch loss:0.15018296	Gen epoch loss:0.22972665
#  * Epoch: [ 0] [2170/20480] Counter:16350	( 8.0 min	44.564 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.48693109	Disc epoch loss:-0.46197437
#    Gen batch loss:0.25193602	Gen epoch loss:0.22868058
#  * Epoch: [ 0] [2220/20480] Counter:16400	( 8.1 min	44.448 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.42169487	Disc epoch loss:-0.46164837
#    Gen batch loss:0.17671052	Gen epoch loss:0.22825728
#  * Epoch: [ 0] [2270/20480] Counter:16450	( 8.4 min	27.162 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.35384706	Disc epoch loss:-0.46154457
#    Gen batch loss:0.26776582	Gen epoch loss:0.22885211
#  * Epoch: [ 0] [2320/20480] Counter:16500	( 8.5 min	44.446 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.42443079	Disc epoch loss:-0.46115295
#    Gen batch loss:0.12313098	Gen epoch loss:0.22916051
#  * Epoch: [ 0] [2370/20480] Counter:16550	( 8.7 min	44.835 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.39794162	Disc epoch loss:-0.46078187
#    Gen batch loss:0.29360214	Gen epoch loss:0.22992590
#  * Epoch: [ 0] [2420/20480] Counter:16600	( 8.8 min	44.510 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.37340814	Disc epoch loss:-0.46054661
#    Gen batch loss:0.05399001	Gen epoch loss:0.23012289
#  * Epoch: [ 0] [2470/20480] Counter:16650	( 9.1 min	26.901 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.48987246	Disc epoch loss:-0.46017431
#    Gen batch loss:0.21002139	Gen epoch loss:0.23004733
#  * Epoch: [ 0] [2520/20480] Counter:16700	( 9.2 min	44.611 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.41545659	Disc epoch loss:-0.45978413
#    Gen batch loss:0.32350773	Gen epoch loss:0.23032523
#  * Epoch: [ 0] [2570/20480] Counter:16750	( 9.4 min	44.335 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.43738151	Disc epoch loss:-0.45941702
#    Gen batch loss:0.16183886	Gen epoch loss:0.22994029
#  * Epoch: [ 0] [2620/20480] Counter:16800	( 9.5 min	44.447 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.41930026	Disc epoch loss:-0.45929474
#    Gen batch loss:0.37006789	Gen epoch loss:0.22911920
#  * Epoch: [ 0] [2670/20480] Counter:16850	( 9.8 min	27.179 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.54520965	Disc epoch loss:-0.45913387
#    Gen batch loss:0.27731091	Gen epoch loss:0.23028809
#  * Epoch: [ 0] [2720/20480] Counter:16900	( 9.9 min	44.151 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.43725264	Disc epoch loss:-0.45896650
#    Gen batch loss:0.15344843	Gen epoch loss:0.23032047
#  * Epoch: [ 0] [2770/20480] Counter:16950	(10.1 min	43.975 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.43725285	Disc epoch loss:-0.45880462
#    Gen batch loss:0.19136515	Gen epoch loss:0.22951397
#  * Epoch: [ 0] [2820/20480] Counter:17000	(10.2 min	44.524 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.45174658	Disc epoch loss:-0.45860411
#    Gen batch loss:0.15827054	Gen epoch loss:0.22923983
# Model saved!
#  * Epoch: [ 0] [2870/20480] Counter:17050	(10.5 min	25.957 examples/sec	0.31 sec/batch)
#    Disc batch loss:-0.46288851	Disc epoch loss:-0.45809536
#    Gen batch loss:0.16767754	Gen epoch loss:0.22961279
#  * Epoch: [ 0] [2920/20480] Counter:17100	(10.6 min	44.508 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.45951658	Disc epoch loss:-0.45780123
#    Gen batch loss:0.09377021	Gen epoch loss:0.22918398
#  * Epoch: [ 0] [2970/20480] Counter:17150	(10.8 min	44.108 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.46474993	Disc epoch loss:-0.45758070
#    Gen batch loss:0.19354382	Gen epoch loss:0.22866133
#  * Epoch: [ 0] [3020/20480] Counter:17200	(10.9 min	44.208 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.50533837	Disc epoch loss:-0.45723310
#    Gen batch loss:0.29082644	Gen epoch loss:0.22901380
#  * Epoch: [ 0] [3070/20480] Counter:17250	(11.2 min	26.481 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.42827922	Disc epoch loss:-0.45701012
#    Gen batch loss:0.31517705	Gen epoch loss:0.22900616
#  * Epoch: [ 0] [3120/20480] Counter:17300	(11.3 min	44.490 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.41363287	Disc epoch loss:-0.45676663
#    Gen batch loss:0.20766567	Gen epoch loss:0.22919248
#  * Epoch: [ 0] [3170/20480] Counter:17350	(11.5 min	43.835 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.43855751	Disc epoch loss:-0.45655204
#    Gen batch loss:0.47212186	Gen epoch loss:0.22956261
#  * Epoch: [ 0] [3220/20480] Counter:17400	(11.6 min	44.478 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.43147677	Disc epoch loss:-0.45626023
#    Gen batch loss:0.21524562	Gen epoch loss:0.22884224
#  * Epoch: [ 0] [3270/20480] Counter:17450	(11.9 min	26.692 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.51339757	Disc epoch loss:-0.45618528
#    Gen batch loss:0.32404578	Gen epoch loss:0.22846583
#  * Epoch: [ 0] [3320/20480] Counter:17500	(12.0 min	44.838 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.39370900	Disc epoch loss:-0.45567972
#    Gen batch loss:0.06581780	Gen epoch loss:0.22842166
#  * Epoch: [ 0] [3370/20480] Counter:17550	(12.2 min	43.952 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.40681520	Disc epoch loss:-0.45557896
#    Gen batch loss:0.26291150	Gen epoch loss:0.22861870
#  * Epoch: [ 0] [3420/20480] Counter:17600	(12.3 min	44.567 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.46595562	Disc epoch loss:-0.45543274
#    Gen batch loss:0.18925485	Gen epoch loss:0.22844279
#  * Epoch: [ 0] [3470/20480] Counter:17650	(12.6 min	27.516 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.37844589	Disc epoch loss:-0.45537790
#    Gen batch loss:0.20669010	Gen epoch loss:0.22788915
#  * Epoch: [ 0] [3520/20480] Counter:17700	(12.7 min	44.360 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.36572388	Disc epoch loss:-0.45522360
#    Gen batch loss:0.09563586	Gen epoch loss:0.22821752
#  * Epoch: [ 0] [3570/20480] Counter:17750	(12.9 min	43.943 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.40212542	Disc epoch loss:-0.45499942
#    Gen batch loss:0.31423533	Gen epoch loss:0.22809993
#  * Epoch: [ 0] [3620/20480] Counter:17800	(13.0 min	44.291 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.44107583	Disc epoch loss:-0.45475931
#    Gen batch loss:0.22358009	Gen epoch loss:0.22774995
#  * Epoch: [ 0] [3670/20480] Counter:17850	(13.3 min	27.571 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.43726811	Disc epoch loss:-0.45438383
#    Gen batch loss:0.07762341	Gen epoch loss:0.22675595
#  * Epoch: [ 0] [3720/20480] Counter:17900	(13.4 min	44.412 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.38483590	Disc epoch loss:-0.45391197
#    Gen batch loss:0.10186379	Gen epoch loss:0.22618234
#  * Epoch: [ 0] [3770/20480] Counter:17950	(13.6 min	44.382 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.52310026	Disc epoch loss:-0.45352539
#    Gen batch loss:0.26797655	Gen epoch loss:0.22555186
#  * Epoch: [ 0] [3820/20480] Counter:18000	(13.7 min	44.278 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.36671716	Disc epoch loss:-0.45317528
#    Gen batch loss:0.05242828	Gen epoch loss:0.22489392
# Model saved!
#  * Epoch: [ 0] [3870/20480] Counter:18050	(14.0 min	26.595 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.39185393	Disc epoch loss:-0.45288935
#    Gen batch loss:0.17734453	Gen epoch loss:0.22450582
#  * Epoch: [ 0] [3920/20480] Counter:18100	(14.1 min	44.111 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.40300709	Disc epoch loss:-0.45258471
#    Gen batch loss:0.35880345	Gen epoch loss:0.22424547
#  * Epoch: [ 0] [3970/20480] Counter:18150	(14.3 min	43.801 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.39602089	Disc epoch loss:-0.45233130
#    Gen batch loss:0.27685073	Gen epoch loss:0.22429973
#  * Epoch: [ 0] [4020/20480] Counter:18200	(14.4 min	44.448 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.33656871	Disc epoch loss:-0.45210666
#    Gen batch loss:0.13622034	Gen epoch loss:0.22409672
#  * Epoch: [ 0] [4070/20480] Counter:18250	(14.7 min	27.695 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.45879531	Disc epoch loss:-0.45194792
#    Gen batch loss:0.20310161	Gen epoch loss:0.22385386
#  * Epoch: [ 0] [4120/20480] Counter:18300	(14.8 min	44.633 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.48678407	Disc epoch loss:-0.45168957
#    Gen batch loss:0.38053221	Gen epoch loss:0.22380428
#  * Epoch: [ 0] [4170/20480] Counter:18350	(15.0 min	44.090 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.43307254	Disc epoch loss:-0.45159047
#    Gen batch loss:0.34271628	Gen epoch loss:0.22389236
#  * Epoch: [ 0] [4220/20480] Counter:18400	(15.1 min	44.687 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.51807362	Disc epoch loss:-0.45130683
#    Gen batch loss:0.15753952	Gen epoch loss:0.22386083
#  * Epoch: [ 0] [4270/20480] Counter:18450	(15.3 min	27.167 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.45420089	Disc epoch loss:-0.45104660
#    Gen batch loss:0.12179342	Gen epoch loss:0.22365910
#  * Epoch: [ 0] [4320/20480] Counter:18500	(15.5 min	44.317 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.43367875	Disc epoch loss:-0.45082543
#    Gen batch loss:0.06176797	Gen epoch loss:0.22390151
#  * Epoch: [ 0] [4370/20480] Counter:18550	(15.6 min	44.465 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.42153984	Disc epoch loss:-0.45057534
#    Gen batch loss:0.37127113	Gen epoch loss:0.22343201
#  * Epoch: [ 0] [4420/20480] Counter:18600	(15.8 min	44.792 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.45139721	Disc epoch loss:-0.45045294
#    Gen batch loss:0.24919781	Gen epoch loss:0.22313024
#  * Epoch: [ 0] [4470/20480] Counter:18650	(16.0 min	26.252 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.43556330	Disc epoch loss:-0.45019173
#    Gen batch loss:0.30846292	Gen epoch loss:0.22334649
#  * Epoch: [ 0] [4520/20480] Counter:18700	(16.2 min	44.403 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.36505610	Disc epoch loss:-0.44992464
#    Gen batch loss:0.03928411	Gen epoch loss:0.22335709
#  * Epoch: [ 0] [4570/20480] Counter:18750	(16.4 min	44.149 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.41032344	Disc epoch loss:-0.44967671
#    Gen batch loss:0.11720249	Gen epoch loss:0.22317120
#  * Epoch: [ 0] [4620/20480] Counter:18800	(16.5 min	44.656 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.39896727	Disc epoch loss:-0.44957078
#    Gen batch loss:0.03884133	Gen epoch loss:0.22291483
#  * Epoch: [ 0] [4670/20480] Counter:18850	(16.7 min	27.319 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.46688357	Disc epoch loss:-0.44939916
#    Gen batch loss:0.35727081	Gen epoch loss:0.22249333
#  * Epoch: [ 0] [4720/20480] Counter:18900	(16.9 min	44.240 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.42876038	Disc epoch loss:-0.44926325
#    Gen batch loss:0.26717985	Gen epoch loss:0.22305571
#  * Epoch: [ 0] [4770/20480] Counter:18950	(17.0 min	43.900 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.37706938	Disc epoch loss:-0.44912397
#    Gen batch loss:0.24189743	Gen epoch loss:0.22298003
#  * Epoch: [ 0] [4820/20480] Counter:19000	(17.2 min	44.197 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.47706756	Disc epoch loss:-0.44886629
#    Gen batch loss:0.30888307	Gen epoch loss:0.22272168
# Model saved!
#  * Epoch: [ 0] [4870/20480] Counter:19050	(17.4 min	26.510 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.49136934	Disc epoch loss:-0.44885670
#    Gen batch loss:0.32090145	Gen epoch loss:0.22235735
#  * Epoch: [ 0] [4920/20480] Counter:19100	(17.6 min	44.270 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.37982276	Disc epoch loss:-0.44858762
#    Gen batch loss:0.16931655	Gen epoch loss:0.22214919
#  * Epoch: [ 0] [4970/20480] Counter:19150	(17.7 min	44.427 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.53678000	Disc epoch loss:-0.44843403
#    Gen batch loss:0.11412282	Gen epoch loss:0.22201379
#  * Epoch: [ 0] [5020/20480] Counter:19200	(17.9 min	44.690 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.49765658	Disc epoch loss:-0.44826818
#    Gen batch loss:0.10829651	Gen epoch loss:0.22207819
#  * Epoch: [ 0] [5070/20480] Counter:19250	(18.1 min	27.197 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.47977930	Disc epoch loss:-0.44802749
#    Gen batch loss:0.24079247	Gen epoch loss:0.22246007
#  * Epoch: [ 0] [5120/20480] Counter:19300	(18.3 min	43.747 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.51659483	Disc epoch loss:-0.44787221
#    Gen batch loss:0.14355743	Gen epoch loss:0.22232282
#  * Epoch: [ 0] [5170/20480] Counter:19350	(18.4 min	44.303 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.36454660	Disc epoch loss:-0.44774243
#    Gen batch loss:0.02716137	Gen epoch loss:0.22210123
#  * Epoch: [ 0] [5220/20480] Counter:19400	(18.6 min	44.576 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.38526064	Disc epoch loss:-0.44748028
#    Gen batch loss:0.10718250	Gen epoch loss:0.22135365
#  * Epoch: [ 0] [5270/20480] Counter:19450	(18.8 min	26.827 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.41267940	Disc epoch loss:-0.44725998
#    Gen batch loss:0.26139510	Gen epoch loss:0.22139375
#  * Epoch: [ 0] [5320/20480] Counter:19500	(19.0 min	44.063 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.46813247	Disc epoch loss:-0.44706959
#    Gen batch loss:0.12655273	Gen epoch loss:0.22105218
#  * Epoch: [ 0] [5370/20480] Counter:19550	(19.1 min	44.539 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.48467240	Disc epoch loss:-0.44682257
#    Gen batch loss:0.15103573	Gen epoch loss:0.22072806
#  * Epoch: [ 0] [5420/20480] Counter:19600	(19.3 min	44.401 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.43547440	Disc epoch loss:-0.44660607
#    Gen batch loss:0.19665569	Gen epoch loss:0.22100276
#  * Epoch: [ 0] [5470/20480] Counter:19650	(19.5 min	26.819 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.42397487	Disc epoch loss:-0.44645030
#    Gen batch loss:0.25596404	Gen epoch loss:0.22102334
#  * Epoch: [ 0] [5520/20480] Counter:19700	(19.7 min	44.008 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.40490618	Disc epoch loss:-0.44617245
#    Gen batch loss:0.04913376	Gen epoch loss:0.22086230
#  * Epoch: [ 0] [5570/20480] Counter:19750	(19.8 min	44.574 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.41646740	Disc epoch loss:-0.44596339
#    Gen batch loss:0.16491142	Gen epoch loss:0.22033162
#  * Epoch: [ 0] [5620/20480] Counter:19800	(20.0 min	44.496 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.35592550	Disc epoch loss:-0.44578895
#    Gen batch loss:0.11521505	Gen epoch loss:0.22018454
#  * Epoch: [ 0] [5670/20480] Counter:19850	(20.2 min	27.050 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.42163000	Disc epoch loss:-0.44567432
#    Gen batch loss:0.11450712	Gen epoch loss:0.21979477
#  * Epoch: [ 0] [5720/20480] Counter:19900	(20.4 min	44.446 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.43327522	Disc epoch loss:-0.44543706
#    Gen batch loss:0.15251255	Gen epoch loss:0.21976792
#  * Epoch: [ 0] [5770/20480] Counter:19950	(20.5 min	44.035 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.34885511	Disc epoch loss:-0.44530237
#    Gen batch loss:0.12011470	Gen epoch loss:0.21985252
#  * Epoch: [ 0] [5820/20480] Counter:20000	(20.7 min	44.198 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.50587434	Disc epoch loss:-0.44514567
#    Gen batch loss:0.22267959	Gen epoch loss:0.21963619
# Model saved!
#  * Epoch: [ 0] [5870/20480] Counter:20050	(20.9 min	26.363 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.44139454	Disc epoch loss:-0.44488035
#    Gen batch loss:0.25746608	Gen epoch loss:0.21975115
#  * Epoch: [ 0] [5920/20480] Counter:20100	(21.1 min	43.946 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.41716206	Disc epoch loss:-0.44472394
#    Gen batch loss:0.18168485	Gen epoch loss:0.21984538
#  * Epoch: [ 0] [5970/20480] Counter:20150	(21.2 min	44.629 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.40712219	Disc epoch loss:-0.44450454
#    Gen batch loss:0.05761790	Gen epoch loss:0.21974953
#  * Epoch: [ 0] [6020/20480] Counter:20200	(21.4 min	44.108 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.46172398	Disc epoch loss:-0.44431572
#    Gen batch loss:0.33916059	Gen epoch loss:0.21983743
#  * Epoch: [ 0] [6070/20480] Counter:20250	(21.6 min	27.184 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.46295065	Disc epoch loss:-0.44419405
#    Gen batch loss:0.22064985	Gen epoch loss:0.21976730
#  * Epoch: [ 0] [6120/20480] Counter:20300	(21.8 min	44.273 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.38334545	Disc epoch loss:-0.44409365
#    Gen batch loss:0.08720085	Gen epoch loss:0.21962561
#  * Epoch: [ 0] [6170/20480] Counter:20350	(21.9 min	44.895 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.38677159	Disc epoch loss:-0.44391800
#    Gen batch loss:0.10185443	Gen epoch loss:0.21974725
#  * Epoch: [ 0] [6220/20480] Counter:20400	(22.1 min	43.977 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.42583537	Disc epoch loss:-0.44378475
#    Gen batch loss:0.21479577	Gen epoch loss:0.21987361
#  * Epoch: [ 0] [6270/20480] Counter:20450	(22.4 min	25.936 examples/sec	0.31 sec/batch)
#    Disc batch loss:-0.37212113	Disc epoch loss:-0.44362449
#    Gen batch loss:0.13208953	Gen epoch loss:0.21992975
#  * Epoch: [ 0] [6320/20480] Counter:20500	(22.5 min	44.261 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.43950051	Disc epoch loss:-0.44348846
#    Gen batch loss:0.18000326	Gen epoch loss:0.21973241
#  * Epoch: [ 0] [6370/20480] Counter:20550	(22.7 min	44.699 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.37051487	Disc epoch loss:-0.44341408
#    Gen batch loss:0.21269506	Gen epoch loss:0.21975755
#  * Epoch: [ 0] [6420/20480] Counter:20600	(22.8 min	43.723 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.37145957	Disc epoch loss:-0.44324262
#    Gen batch loss:0.02831868	Gen epoch loss:0.21967415
#  * Epoch: [ 0] [6470/20480] Counter:20650	(23.0 min	27.200 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.41909698	Disc epoch loss:-0.44305032
#    Gen batch loss:0.18459408	Gen epoch loss:0.21981661
#  * Epoch: [ 0] [6520/20480] Counter:20700	(23.2 min	44.308 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.48710945	Disc epoch loss:-0.44296245
#    Gen batch loss:0.19787121	Gen epoch loss:0.22000274
#  * Epoch: [ 0] [6570/20480] Counter:20750	(23.3 min	44.991 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.37938213	Disc epoch loss:-0.44274541
#    Gen batch loss:0.17982695	Gen epoch loss:0.22000009
#  * Epoch: [ 0] [6620/20480] Counter:20800	(23.5 min	43.921 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.40744630	Disc epoch loss:-0.44254945
#    Gen batch loss:0.32053286	Gen epoch loss:0.22013392
#  * Epoch: [ 0] [6670/20480] Counter:20850	(23.7 min	27.138 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.41910121	Disc epoch loss:-0.44238291
#    Gen batch loss:0.32041219	Gen epoch loss:0.22030042
#  * Epoch: [ 0] [6720/20480] Counter:20900	(23.9 min	44.183 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.40955162	Disc epoch loss:-0.44218935
#    Gen batch loss:0.12102015	Gen epoch loss:0.22019984
#  * Epoch: [ 0] [6770/20480] Counter:20950	(24.0 min	44.744 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.43556178	Disc epoch loss:-0.44204144
#    Gen batch loss:0.31641576	Gen epoch loss:0.22025567
#  * Epoch: [ 0] [6820/20480] Counter:21000	(24.2 min	44.273 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.49020526	Disc epoch loss:-0.44186028
#    Gen batch loss:0.19002648	Gen epoch loss:0.22005992
# Model saved!
#  * Epoch: [ 0] [6870/20480] Counter:21050	(24.5 min	26.182 examples/sec	0.31 sec/batch)
#    Disc batch loss:-0.37220666	Disc epoch loss:-0.44172106
#    Gen batch loss:0.01814915	Gen epoch loss:0.21984309
#  * Epoch: [ 0] [6920/20480] Counter:21100	(24.6 min	43.549 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.37424067	Disc epoch loss:-0.44163712
#    Gen batch loss:0.36603436	Gen epoch loss:0.21998792
#  * Epoch: [ 0] [6970/20480] Counter:21150	(24.8 min	44.989 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.41257128	Disc epoch loss:-0.44140720
#    Gen batch loss:0.22856590	Gen epoch loss:0.21977020
#  * Epoch: [ 0] [7020/20480] Counter:21200	(24.9 min	44.394 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.37785789	Disc epoch loss:-0.44125939
#    Gen batch loss:0.19014607	Gen epoch loss:0.22001254
#  * Epoch: [ 0] [7070/20480] Counter:21250	(25.2 min	26.652 examples/sec	0.30 sec/batch)
#    Disc batch loss:-0.39528698	Disc epoch loss:-0.44115639
#    Gen batch loss:0.34932679	Gen epoch loss:0.22011844
#  * Epoch: [ 0] [7120/20480] Counter:21300	(25.3 min	44.086 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.39013958	Disc epoch loss:-0.44093616
#    Gen batch loss:0.22348177	Gen epoch loss:0.21993802
#  * Epoch: [ 0] [7170/20480] Counter:21350	(25.5 min	44.589 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.45102346	Disc epoch loss:-0.44074461
#    Gen batch loss:0.05120045	Gen epoch loss:0.21942295
#  * Epoch: [ 0] [7220/20480] Counter:21400	(25.6 min	44.021 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.47196153	Disc epoch loss:-0.44052822
#    Gen batch loss:0.27696782	Gen epoch loss:0.21960029
#  * Epoch: [ 0] [7270/20480] Counter:21450	(25.8 min	27.389 examples/sec	0.29 sec/batch)
#    Disc batch loss:-0.41824993	Disc epoch loss:-0.44034731
#    Gen batch loss:0.08455671	Gen epoch loss:0.21926801
#  * Epoch: [ 0] [7320/20480] Counter:21500	(26.0 min	43.980 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.39954534	Disc epoch loss:-0.44018326
#    Gen batch loss:0.12428004	Gen epoch loss:0.21912872
#  * Epoch: [ 0] [7370/20480] Counter:21550	(26.1 min	44.184 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.47317669	Disc epoch loss:-0.43999846
#    Gen batch loss:0.26631796	Gen epoch loss:0.21912721
#  * Epoch: [ 0] [7420/20480] Counter:21600	(26.3 min	43.777 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.35510525	Disc epoch loss:-0.43980142
#    Gen batch loss:0.24065289	Gen epoch loss:0.21896024
#  * Epoch: [ 0] [7570/20480] Counter:21750	(26.8 min	44.995 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.38689688	Disc epoch loss:-0.43936281
#    Gen batch loss:0.17520376	Gen epoch loss:0.21861442
#  * Epoch: [ 0] [7620/20480] Counter:21800	(27.0 min	44.491 examples/sec	0.18 sec/batch)
#    Disc batch loss:-0.44680530	Disc epoch loss:-0.43918802
#    Gen batch loss:0.36689514	Gen epoch loss:0.21864609

# %% [markdown]
# # Generate new samples
# To have meaningful statistics, be sure to generate enough samples
# * 2000 : 32 x 32
# * 500 : 64 x 64
# * 200 : 128 x 128

# %%
_, params = utils.test_resume(True, params)
wgan = UpscaleGANsystem(CosmoUpscalePatchWGAN, params)
# Out:
# Resume, the training will start from the last iteration!
# Apply attenuation to borders
# Generator
# --------------------------------------------------
#      The input is of size (?, 1024)
#      Reshape to (?, 32, 32, 1)
#      Contenate with latent variables to (?, 32, 32, 5)
#      0 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      1 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      2 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      3 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      4 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      5 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      6 Inception conv(1x1,3x3,5x5) layer with 32 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32)
#      7 Inception conv(1x1,3x3,5x5) layer with 1 channels
#          Size of the variables: (?, 32, 32, 1)
#     Costum non linearity: <function relu at 0x7fd5c30ed0d0>
#      The output is of size (?, 32, 32, 1)
# --------------------------------------------------
#
# Discriminator
# --------------------------------------------------
#      The input is of size (?, 64, 64, 3)
#      0 Inception(1x1,3x3,5x5) layer with 64 channels
#          Size of the variables: (?, 32, 32, 64)
#      1 Inception(1x1,3x3,5x5) layer with 64 channels
#          Size of the variables: (?, 16, 16, 64)
#      2 Inception(1x1,3x3,5x5) layer with 32 channels
#          Size of the variables: (?, 8, 8, 32)
#      3 Inception(1x1,3x3,5x5) layer with 16 channels
#          Size of the variables: (?, 8, 8, 16)
#      4 Inception(1x1,3x3,5x5) layer with 8 channels
#          Size of the variables: (?, 8, 8, 8)
#      5 Inception(1x1,3x3,5x5) layer with 2 channels
#          Size of the variables: (?, 8, 8, 2)
#      Reshape to (?, 128)
#      6 Full layer with 64 outputs
#          Size of the variables: (?, 64)
#      7 Full layer with 16 outputs
#          Size of the variables: (?, 16)
#      8 Full layer with 1 outputs
#      The output is of size (?, 1)
# --------------------------------------------------
#
#  Wasserstein loss with gamma_gp=10
#  Using gradients penalty
# Add summary for descriptives/mean_real
# Add summary for descriptives/var_real
# Add summary for descriptives/min_real
# Add summary for descriptives/max_real
# Add summary for descriptives/kurtosis_real
# Add summary for descriptives/skewness_real
# Add summary for descriptives/median_real
# Add summary for descriptives/mean_fake
# Add summary for descriptives/var_fake
# Add summary for descriptives/min_fake
# Add summary for descriptives/max_fake
# Add summary for descriptives/kurtosis_fake
# Add summary for descriptives/skewness_fake
# Add summary for descriptives/median_fake
# Add summary for descriptives/mean_l2
# Add summary for descriptives/var_l2
# Add summary for descriptives/min_l2
# Add summary for descriptives/max_l2
# Add summary for descriptives/kurtosis_l2
# Add summary for descriptives/skewness_l2
# Add summary for descriptives/median_l2
# Add summary for cosmology/mass_histogram_l2log
# Add summary for cosmology/peak_histogram_l2log
# Add summary for cosmology/psd_l2log
# Add summary for cosmology/global_score
#
# Build the optimizers:
#  * discriminator
# kwargs: {}
# learning_rate: 3.0e-05
# optimizer: rmsprop
#
#  * generator
# kwargs: {}
# learning_rate: 3.0e-05
# optimizer: rmsprop
#
# ---------
# Variables: name (type shape) [size]
# ---------
# generator/0_conv_1_by_1/w:0 (float32_ref 1x1x5x32) [160, bytes: 640]
# generator/0_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/0_conv_3_by_3/w:0 (float32_ref 3x3x5x32) [1440, bytes: 5760]
# generator/0_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/0_conv_5_by_5/w:0 (float32_ref 5x5x5x32) [4000, bytes: 16000]
# generator/0_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/0_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/0_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/1_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/1_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/1_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/1_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/1_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/2_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/2_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/2_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/2_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/2_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/3_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/3_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/3_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/3_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/3_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/4_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/4_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/4_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/4_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/4_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/5_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/5_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/5_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/5_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/5_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_1_by_1/w:0 (float32_ref 1x1x32x32) [1024, bytes: 4096]
# generator/6_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_3_by_3/w:0 (float32_ref 3x3x32x32) [9216, bytes: 36864]
# generator/6_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_5_by_5/w:0 (float32_ref 5x5x32x32) [25600, bytes: 102400]
# generator/6_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/6_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# generator/6_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# generator/7_conv_1_by_1/w:0 (float32_ref 1x1x32x1) [32, bytes: 128]
# generator/7_conv_1_by_1/biases:0 (float32_ref 1) [1, bytes: 4]
# generator/7_conv_3_by_3/w:0 (float32_ref 3x3x32x1) [288, bytes: 1152]
# generator/7_conv_3_by_3/biases:0 (float32_ref 1) [1, bytes: 4]
# generator/7_conv_5_by_5/w:0 (float32_ref 5x5x32x1) [800, bytes: 3200]
# generator/7_conv_5_by_5/biases:0 (float32_ref 1) [1, bytes: 4]
# generator/7_conv_1_by_1_merge/w:0 (float32_ref 1x1x3x1) [3, bytes: 12]
# generator/7_conv_1_by_1_merge/biases:0 (float32_ref 1) [1, bytes: 4]
# discriminator/0_conv_1_by_1/w:0 (float32_ref 1x1x3x64) [192, bytes: 768]
# discriminator/0_conv_1_by_1/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/0_conv_3_by_3/w:0 (float32_ref 3x3x3x64) [1728, bytes: 6912]
# discriminator/0_conv_3_by_3/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/0_conv_5_by_5/w:0 (float32_ref 5x5x3x64) [4800, bytes: 19200]
# discriminator/0_conv_5_by_5/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/0_conv_1_by_1_merge/w:0 (float32_ref 1x1x192x64) [12288, bytes: 49152]
# discriminator/0_conv_1_by_1_merge/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_1_by_1/w:0 (float32_ref 1x1x64x64) [4096, bytes: 16384]
# discriminator/1_conv_1_by_1/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_3_by_3/w:0 (float32_ref 3x3x64x64) [36864, bytes: 147456]
# discriminator/1_conv_3_by_3/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_5_by_5/w:0 (float32_ref 5x5x64x64) [102400, bytes: 409600]
# discriminator/1_conv_5_by_5/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_1_by_1_merge/w:0 (float32_ref 1x1x192x64) [12288, bytes: 49152]
# discriminator/1_conv_1_by_1_merge/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/2_conv_1_by_1/w:0 (float32_ref 1x1x64x32) [2048, bytes: 8192]
# discriminator/2_conv_1_by_1/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/2_conv_3_by_3/w:0 (float32_ref 3x3x64x32) [18432, bytes: 73728]
# discriminator/2_conv_3_by_3/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/2_conv_5_by_5/w:0 (float32_ref 5x5x64x32) [51200, bytes: 204800]
# discriminator/2_conv_5_by_5/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/2_conv_1_by_1_merge/w:0 (float32_ref 1x1x96x32) [3072, bytes: 12288]
# discriminator/2_conv_1_by_1_merge/biases:0 (float32_ref 32) [32, bytes: 128]
# discriminator/3_conv_1_by_1/w:0 (float32_ref 1x1x32x16) [512, bytes: 2048]
# discriminator/3_conv_1_by_1/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/3_conv_3_by_3/w:0 (float32_ref 3x3x32x16) [4608, bytes: 18432]
# discriminator/3_conv_3_by_3/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/3_conv_5_by_5/w:0 (float32_ref 5x5x32x16) [12800, bytes: 51200]
# discriminator/3_conv_5_by_5/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/3_conv_1_by_1_merge/w:0 (float32_ref 1x1x48x16) [768, bytes: 3072]
# discriminator/3_conv_1_by_1_merge/biases:0 (float32_ref 16) [16, bytes: 64]
# discriminator/4_conv_1_by_1/w:0 (float32_ref 1x1x16x8) [128, bytes: 512]
# discriminator/4_conv_1_by_1/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/4_conv_3_by_3/w:0 (float32_ref 3x3x16x8) [1152, bytes: 4608]
# discriminator/4_conv_3_by_3/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/4_conv_5_by_5/w:0 (float32_ref 5x5x16x8) [3200, bytes: 12800]
# discriminator/4_conv_5_by_5/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/4_conv_1_by_1_merge/w:0 (float32_ref 1x1x24x8) [192, bytes: 768]
# discriminator/4_conv_1_by_1_merge/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/5_conv_1_by_1/w:0 (float32_ref 1x1x8x2) [16, bytes: 64]
# discriminator/5_conv_1_by_1/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/5_conv_3_by_3/w:0 (float32_ref 3x3x8x2) [144, bytes: 576]
# discriminator/5_conv_3_by_3/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/5_conv_5_by_5/w:0 (float32_ref 5x5x8x2) [400, bytes: 1600]
# discriminator/5_conv_5_by_5/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/5_conv_1_by_1_merge/w:0 (float32_ref 1x1x6x2) [12, bytes: 48]
# discriminator/5_conv_1_by_1_merge/biases:0 (float32_ref 2) [2, bytes: 8]
# discriminator/6_full/Matrix:0 (float32_ref 128x64) [8192, bytes: 32768]
# discriminator/6_full/bias:0 (float32_ref 64) [64, bytes: 256]
# discriminator/7_full/Matrix:0 (float32_ref 64x16) [1024, bytes: 4096]
# discriminator/7_full/bias:0 (float32_ref 16) [16, bytes: 64]
# discriminator/out/Matrix:0 (float32_ref 16x1) [16, bytes: 64]
# discriminator/out/bias:0 (float32_ref 1) [1, bytes: 4]
# Total size of variables: 527564
# Total bytes of variables: 2110256
# Add summary for cosmology/mass_histogram_l2log
# Add summary for cosmology/peak_histogram_l2log
# Add summary for cosmology/psd_l2log
# Add summary for cosmology/global_score

# %%
from gantools.blocks import downsample

# %%
Nsample = 512
X_real = dataset._X[:Nsample]
X_down = downsample(X_real, 4)

# %%
X_fake = wgan.upscale_image(small=np.expand_dims(X_down, axis=3))
# Out:
#  [*] Reading checkpoints...
# saved_results/WGAN32_2D_patchgan_up_weights_checkpoints/upscale_patch_wgan-99491
# The last checkpoint is found at saved_results/WGAN32_2D_patchgan_up_weights_checkpoints/upscale_patch_wgan-99491
# INFO:tensorflow:Restoring parameters from saved_results/WGAN32_2D_patchgan_up_weights_checkpoints/upscale_patch_wgan-99491
# Checkpoint successfully loaded!
# (512, 64, 64, 1)
# Current patch: column=1, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=1, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=1, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=1, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=1, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=1, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=1, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=1, row=8
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=2, row=8
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=3, row=8
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=4, row=8
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=5, row=8
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=6, row=8
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=7, row=8
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=1
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=2
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=3
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=4
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=5
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=6
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=7
# Sampling z
# (512, 64, 64, 1)
# Current patch: column=8, row=8
# Sampling z

# %% [markdown]
# Display a few fake samples

# %%
clim = (0,3)
plt.figure(figsize=(30,10))
plt.subplot(131)
plot.draw_images(X_fake,nx=1,ny=1,vmin=clim[0], vmax=clim[1], cmap = plt.cm.plasma);

plt.title("Fake samples");
plt.subplot(132)
plot.draw_images(X_real,nx=1,ny=1,vmin=clim[0], vmax=clim[1], cmap = plt.cm.plasma);
plt.title("Real samples");
plt.subplot(133)
plot.draw_images(X_down,nx=1,ny=1,vmin=clim[0], vmax=clim[1], cmap = plt.cm.plasma);
plt.title("Down samples");

# %% [markdown]
# # Evaluation of the sample quality

# %%
# Before computing the statistics, we need to invert the mapping
raw_images = backward(X_real)
gen_sample_raw = backward(X_fake)

# %%
logel2, l2, logel1, l1 = evaluation.compute_and_plot_psd(raw_images, gen_sample_raw)
# Out:
# Log l2 PSD loss: 1.956829683342675
# L2 PSD loss: 581.086131908902
# Log l1 PSD loss: 1.3296848650058746
# L1 PSD loss: 18.318963932530153

# %%
logel2, l2, logel1, l1 = evaluation.compute_and_plot_peak_cout(raw_images, gen_sample_raw)
# Out:
# Log l2 Peak Count loss: 0.0562925575829122
# L2 Peak Count loss: 5.9306112656043674e-06
# Log l1 Peak Count loss: 0.1541863749832798
# L1 Peak Count loss: 0.0015570842358864226

# %%
logel2, l2, logel1, l1 = evaluation.compute_and_plot_mass_hist(raw_images, gen_sample_raw)
# Out:
# Log l2 Mass histogram loss: 0.14500927118712675
# L2 Peak Mass histogram: 7.264700165476867e-05
# Log l1 Mass histogram loss: 0.18266686099981477
# L1 Mass histogram loss: 0.0033612668514251707
