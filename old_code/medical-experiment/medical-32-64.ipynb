# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import tensorflow as tf
import os, functools
from gantools import data, utils
from gantools.model import UpscalePatchWGAN
from gantools.gansystem import GANsystem

os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
ns = 32
try_resume = False
latent_dim = 32*32*32

time_str = '32_to_64' 
global_path = '../saved_result/medical/'
name = 'WGAN_'+time_str

def non_lin(x):
    return (tf.nn.tanh(x) + 1.0)/2.0

bn = False

md = 8

params_discriminator = dict()
params_discriminator['stride'] = [2, 2, 2, 1, 1, 1]
params_discriminator['nfilter'] = [md, md*8, md*8, md*8, md, md]
params_discriminator['inception'] = True
params_discriminator['batch_norm'] = [bn, bn, bn, bn, bn, bn]
params_discriminator['full'] = []
params_discriminator['summary'] = True
params_discriminator['minibatch_reg'] = False
params_discriminator['data_size'] = 3


params_generator = dict()
params_generator['stride'] = [1, 1, 1, 1, 1, 1]
params_generator['latent_dim'] = latent_dim
params_generator['nfilter'] = [md, 2*md, 2*md, 2*md, 2*md, 1]
params_generator['inception'] = True
params_generator['batch_norm'] = [bn, bn, bn, bn, bn]
params_generator['full'] = []
params_generator['summary'] = True
params_generator['non_lin'] = non_lin
params_generator['data_size'] = 3

params_optimization = dict()
params_optimization['n_critic'] = 10
params_optimization['batch_size'] = 8
params_optimization['epoch'] = 10000

params = dict()
params['net'] = dict()
params['net']['shape'] = [ns, ns, ns, 8]
params['net']['generator'] = params_generator
params['net']['gamma'] = 10
params['net']['discriminator'] = params_discriminator
params['net']['upscaling'] = 2

params['optimization'] = params_optimization
params['summary_every'] = 100 # Tensorboard summaries every ** iterations
params['print_every'] = 50 # Console summaries every ** iterations
params['save_every'] = 1000 # Save the model every ** iterations
params['summary_dir'] = os.path.join(global_path, name +'_summary/')
params['save_dir'] = os.path.join(global_path, name + '_checkpoints/')
params['Nstats'] = 10

resume, params = utils.test_resume(try_resume, params)

# %%
wgan = GANsystem(UpscalePatchWGAN, params)
# Out:
# Generator
# --------------------------------------------------
#      The input is of size (?, 32768)
#      Reshape to (?, 32, 32, 32, 1)
#      Contenate with latent variables to (?, 32, 32, 32, 8)
#      0 Inception conv(1x1,3x3,5x5) layer with 8 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32, 24)
#      1 Inception conv(1x1,3x3,5x5) layer with 8 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32, 24)
#      2 Inception conv(1x1,3x3,5x5) layer with 8 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32, 24)
#      3 Inception conv(1x1,3x3,5x5) layer with 8 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32, 24)
#      4 Inception conv(1x1,3x3,5x5) layer with 8 channels
#          Non linearity applied
#          Size of the variables: (?, 32, 32, 32, 24)
#      5 Inception conv(1x1,3x3,5x5) layer with 1 channels
#          Size of the variables: (?, 32, 32, 32, 1)
#     Costum non linearity: <function non_lin at 0x7f17c01d40d0>
#      The output is of size (?, 32, 32, 32, 1)
# --------------------------------------------------
#
# Discriminator
# --------------------------------------------------
#      The input is of size (?, 64, 64, 64, 1)
#      0 Inception(1x1,3x3,5x5) layer with 8 channels
#          Size of the variables: (?, 32, 32, 32, 24)
#      1 Inception(1x1,3x3,5x5) layer with 64 channels
#          Size of the variables: (?, 16, 16, 16, 192)
#      2 Inception(1x1,3x3,5x5) layer with 64 channels
#          Size of the variables: (?, 8, 8, 8, 192)
#      3 Inception(1x1,3x3,5x5) layer with 64 channels
#          Size of the variables: (?, 8, 8, 8, 192)
#      4 Inception(1x1,3x3,5x5) layer with 8 channels
#          Size of the variables: (?, 8, 8, 8, 24)
#      5 Inception(1x1,3x3,5x5) layer with 8 channels
#          Size of the variables: (?, 8, 8, 8, 8)
#      Reshape to (?, 4096)
#      6 Full layer with 1 outputs
#      The output is of size (?, 1)
# --------------------------------------------------
#
#  Using gradients clipping
# Add summary for descriptives/mean_real
# Add summary for descriptives/var_real
# Add summary for descriptives/min_real
# Add summary for descriptives/max_real
# Add summary for descriptives/kurtosis_real
# Add summary for descriptives/skewness_real
# Add summary for descriptives/median_real
# Add summary for descriptives/mean_fake
# Add summary for descriptives/var_fake
# Add summary for descriptives/min_fake
# Add summary for descriptives/max_fake
# Add summary for descriptives/kurtosis_fake
# Add summary for descriptives/skewness_fake
# Add summary for descriptives/median_fake
# Add summary for descriptives/mean_l2
# Add summary for descriptives/var_l2
# Add summary for descriptives/min_l2
# Add summary for descriptives/max_l2
# Add summary for descriptives/kurtosis_l2
# Add summary for descriptives/skewness_l2
# Add summary for descriptives/median_l2
# Add summary for final/mass_histogram_l2
# Add summary for final/peak_histogram_l2
# Add summary for final/psd_l2log
# Add summary for final/global_score
# Add summary for wasserstein/mass_histogram_l2
# Add summary for wasserstein/psd_l2
# Add summary for wasserstein/global_score
# ---------
# Variables: name (type shape) [size]
# ---------
# generator/0_conv_1_by_1/w:0 (float32_ref 1x1x1x8x8) [64, bytes: 256]
# generator/0_conv_1_by_1/biases:0 (float32_ref 8) [8, bytes: 32]
# generator/0_conv_3_by_3/w:0 (float32_ref 3x3x3x8x8) [1728, bytes: 6912]
# generator/0_conv_3_by_3/biases:0 (float32_ref 8) [8, bytes: 32]
# generator/0_conv_5_by_5/w:0 (float32_ref 5x5x5x8x8) [8000, bytes: 32000]
# generator/0_conv_5_by_5/biases:0 (float32_ref 8) [8, bytes: 32]
# generator/1_conv_1_by_1/w:0 (float32_ref 1x1x1x24x8) [192, bytes: 768]
# generator/1_conv_1_by_1/biases:0 (float32_ref 8) [8, bytes: 32]
# generator/1_conv_3_by_3/w:0 (float32_ref 3x3x3x24x8) [5184, bytes: 20736]
# generator/1_conv_3_by_3/biases:0 (float32_ref 8) [8, bytes: 32]
# generator/1_conv_5_by_5/w:0 (float32_ref 5x5x5x24x8) [24000, bytes: 96000]
# generator/1_conv_5_by_5/biases:0 (float32_ref 8) [8, bytes: 32]
# generator/2_conv_1_by_1/w:0 (float32_ref 1x1x1x24x8) [192, bytes: 768]
# generator/2_conv_1_by_1/biases:0 (float32_ref 8) [8, bytes: 32]
# generator/2_conv_3_by_3/w:0 (float32_ref 3x3x3x24x8) [5184, bytes: 20736]
# generator/2_conv_3_by_3/biases:0 (float32_ref 8) [8, bytes: 32]
# generator/2_conv_5_by_5/w:0 (float32_ref 5x5x5x24x8) [24000, bytes: 96000]
# generator/2_conv_5_by_5/biases:0 (float32_ref 8) [8, bytes: 32]
# generator/3_conv_1_by_1/w:0 (float32_ref 1x1x1x24x8) [192, bytes: 768]
# generator/3_conv_1_by_1/biases:0 (float32_ref 8) [8, bytes: 32]
# generator/3_conv_3_by_3/w:0 (float32_ref 3x3x3x24x8) [5184, bytes: 20736]
# generator/3_conv_3_by_3/biases:0 (float32_ref 8) [8, bytes: 32]
# generator/3_conv_5_by_5/w:0 (float32_ref 5x5x5x24x8) [24000, bytes: 96000]
# generator/3_conv_5_by_5/biases:0 (float32_ref 8) [8, bytes: 32]
# generator/4_conv_1_by_1/w:0 (float32_ref 1x1x1x24x8) [192, bytes: 768]
# generator/4_conv_1_by_1/biases:0 (float32_ref 8) [8, bytes: 32]
# generator/4_conv_3_by_3/w:0 (float32_ref 3x3x3x24x8) [5184, bytes: 20736]
# generator/4_conv_3_by_3/biases:0 (float32_ref 8) [8, bytes: 32]
# generator/4_conv_5_by_5/w:0 (float32_ref 5x5x5x24x8) [24000, bytes: 96000]
# generator/4_conv_5_by_5/biases:0 (float32_ref 8) [8, bytes: 32]
# generator/5_conv_1_by_1/w:0 (float32_ref 1x1x1x24x1) [24, bytes: 96]
# generator/5_conv_1_by_1/biases:0 (float32_ref 1) [1, bytes: 4]
# generator/5_conv_3_by_3/w:0 (float32_ref 3x3x3x24x1) [648, bytes: 2592]
# generator/5_conv_3_by_3/biases:0 (float32_ref 1) [1, bytes: 4]
# generator/5_conv_5_by_5/w:0 (float32_ref 5x5x5x24x1) [3000, bytes: 12000]
# generator/5_conv_5_by_5/biases:0 (float32_ref 1) [1, bytes: 4]
# generator/5_conv_1_by_1_merge/w:0 (float32_ref 1x1x1x3x1) [3, bytes: 12]
# generator/5_conv_1_by_1_merge/biases:0 (float32_ref 1) [1, bytes: 4]
# discriminator/0_conv_1_by_1/w:0 (float32_ref 1x1x1x1x8) [8, bytes: 32]
# discriminator/0_conv_1_by_1/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/0_conv_3_by_3/w:0 (float32_ref 3x3x3x1x8) [216, bytes: 864]
# discriminator/0_conv_3_by_3/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/0_conv_5_by_5/w:0 (float32_ref 5x5x5x1x8) [1000, bytes: 4000]
# discriminator/0_conv_5_by_5/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/1_conv_1_by_1/w:0 (float32_ref 1x1x1x24x64) [1536, bytes: 6144]
# discriminator/1_conv_1_by_1/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_3_by_3/w:0 (float32_ref 3x3x3x24x64) [41472, bytes: 165888]
# discriminator/1_conv_3_by_3/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/1_conv_5_by_5/w:0 (float32_ref 5x5x5x24x64) [192000, bytes: 768000]
# discriminator/1_conv_5_by_5/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/2_conv_1_by_1/w:0 (float32_ref 1x1x1x192x64) [12288, bytes: 49152]
# discriminator/2_conv_1_by_1/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/2_conv_3_by_3/w:0 (float32_ref 3x3x3x192x64) [331776, bytes: 1327104]
# discriminator/2_conv_3_by_3/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/2_conv_5_by_5/w:0 (float32_ref 5x5x5x192x64) [1536000, bytes: 6144000]
# discriminator/2_conv_5_by_5/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/3_conv_1_by_1/w:0 (float32_ref 1x1x1x192x64) [12288, bytes: 49152]
# discriminator/3_conv_1_by_1/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/3_conv_3_by_3/w:0 (float32_ref 3x3x3x192x64) [331776, bytes: 1327104]
# discriminator/3_conv_3_by_3/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/3_conv_5_by_5/w:0 (float32_ref 5x5x5x192x64) [1536000, bytes: 6144000]
# discriminator/3_conv_5_by_5/biases:0 (float32_ref 64) [64, bytes: 256]
# discriminator/4_conv_1_by_1/w:0 (float32_ref 1x1x1x192x8) [1536, bytes: 6144]
# discriminator/4_conv_1_by_1/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/4_conv_3_by_3/w:0 (float32_ref 3x3x3x192x8) [41472, bytes: 165888]
# discriminator/4_conv_3_by_3/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/4_conv_5_by_5/w:0 (float32_ref 5x5x5x192x8) [192000, bytes: 768000]
# discriminator/4_conv_5_by_5/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/5_conv_1_by_1/w:0 (float32_ref 1x1x1x24x8) [192, bytes: 768]
# discriminator/5_conv_1_by_1/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/5_conv_3_by_3/w:0 (float32_ref 3x3x3x24x8) [5184, bytes: 20736]
# discriminator/5_conv_3_by_3/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/5_conv_5_by_5/w:0 (float32_ref 5x5x5x24x8) [24000, bytes: 96000]
# discriminator/5_conv_5_by_5/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/5_conv_1_by_1_merge/w:0 (float32_ref 1x1x1x24x8) [192, bytes: 768]
# discriminator/5_conv_1_by_1_merge/biases:0 (float32_ref 8) [8, bytes: 32]
# discriminator/out/Matrix:0 (float32_ref 4096x1) [4096, bytes: 16384]
# discriminator/out/bias:0 (float32_ref 1) [1, bytes: 4]
# Total size of variables: 4396784
# Total bytes of variables: 17587136

# %%
dataset = data.load.load_medical_dataset(spix=ns, scaling=4, patch=True, augmentation=True)

# %%
wgan.train(dataset, resume=resume)
# Out:
# Compute real statistics: descriptives/mean_l2
# Compute real statistics: descriptives/var_l2
# Compute real statistics: descriptives/min_l2
# Compute real statistics: descriptives/max_l2
# Compute real statistics: descriptives/kurtosis_l2
# Compute real statistics: descriptives/skewness_l2
# Compute real statistics: descriptives/median_l2
# Compute real statistics: final/mass_histogram_l2
# Compute real statistics: final/peak_histogram_l2
# Compute real statistics: final/psd_l2log
# Compute real statistics: wasserstein/mass_histogram_l2
# Compute real statistics: wasserstein/psd_l2
# Erase recursively directory: ../saved_result/medical/WGAN_32_to_64_summary/
# Erase recursively directory: ../saved_result/medical/WGAN_32_to_64_checkpoints/
# Start training
# Model saved!
